# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('raw.githubusercontent.com_OmdenaAI_rwanda-chapter-water-quality-prediction_main_src_data_Synthetic_Data_Water_Quality.csv_token=GHSAT0AAAAAACDPMDQNJQY6HC4V722ZW3VCZEIDFVQ.csv')

# %%
df
# Out:
#       Colour (TCU)  Turbidity (NTU)    pH  Conductivity (uS/cm)  \
# 0             8.34             3.39  8.06                819.00
# 1            14.45             3.36  8.28               1371.10
# 2             3.87             4.23  6.86                202.75
# 3            14.57             1.75  7.00                696.16
# 4             9.01             2.20  6.73                129.24
# ...            ...              ...   ...                   ...
# 9995         27.64             9.46  0.09               2422.27
# 9996         25.58             8.61  4.39               1516.78
# 9997         19.40             8.16  3.05               2456.68
# 9998         18.73             5.03  9.35               1900.45
# 9999         27.30             8.66  9.22               2750.24
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                            787.15                          279.89
# 1                            779.66                          112.04
# 2                            485.10                          113.17
# 3                            409.71                          140.39
# 4                            343.55                            6.52
# ...                             ...                             ...
# 9995                        1147.04                          521.18
# 9996                        1604.78                          429.84
# 9997                        1439.54                          483.23
# 9998                        1092.84                          458.86
# 9999                        1058.46                          492.12
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0                 0.09           129.30               0.22          13.13
# 1                 0.20           163.73               0.13         127.48
# 2                 0.15            66.68               0.29         142.97
# 3                 0.06           102.42               0.15         194.07
# 4                 0.07           140.47               0.28           3.77
# ...                ...              ...                ...            ...
# 9995              0.24           362.50               0.41         283.40
# 9996              0.33           394.23               0.55         303.78
# 9997              0.40           348.95               0.48         229.37
# 9998              0.28           289.98               0.52         310.67
# 9999              0.35           283.16               0.59         247.13
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0               81.01         2.24             12.69          107.95
# 1              307.99         4.05             52.01          107.12
# 2               16.70         0.86             88.47          127.47
# 3              393.09         2.60             61.36           99.16
# 4              170.65         0.04             47.22          107.17
# ...               ...          ...               ...             ...
# 9995           438.94         9.88            112.00          258.93
# 9996           556.85         8.87            122.23          284.79
# 9997           690.85         6.67            136.61          198.87
# 9998           564.05         7.22            108.37          260.68
# 9999           423.96         8.42            149.07          266.26
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)   Potability
# 0                17.50           22.23              0.41      potable
# 1                45.28           16.06              0.68      potable
# 2                 4.90           19.81              0.91      potable
# 3                36.73           42.82              0.02      potable
# 4                44.79           14.35              2.08      potable
# ...                ...             ...               ...          ...
# 9995             70.92           81.10              3.09  non-potable
# 9996             76.31           79.69              2.48  non-potable
# 9997             68.99           53.38              3.37  non-potable
# 9998             82.73           83.58              2.78  non-potable
# 9999             87.11           51.96              4.11  non-potable
#
# [10000 rows x 18 columns]

# %%
df['Potability'].value_counts()
# Out:
# potable        5000
# non-potable    5000
# Name: Potability, dtype: int64

# %%
df.corr()
# Out:
#                                 Colour (TCU)  Turbidity (NTU)        pH  \
# Colour (TCU)                        1.000000         0.754021 -0.043882
# Turbidity (NTU)                     0.754021         1.000000 -0.039172
# pH                                 -0.043882        -0.039172  1.000000
# Conductivity (uS/cm)                0.753990         0.752617 -0.042363
# Total Dissolved Solids (mg/l)       0.748718         0.755528 -0.044006
# Total Hardness (mg/l as CaCO3)      0.745498         0.749558 -0.044394
# Aluminium (mg/l)                    0.750874         0.748596 -0.051973
# Chloride (mg/l)                     0.747499         0.754928 -0.048232
# Total Iron (mg/l)                   0.756394         0.749736 -0.051106
# Sodium (mg/l)                       0.751185         0.753077 -0.045605
# Sulphate (mg/l)                     0.750063         0.751699 -0.041821
# Zinc (mg/l)                         0.752901         0.753478 -0.042260
# Magnesium (mg/l)                    0.750764         0.751698 -0.049970
# Calcium (mg/l)                      0.753162         0.756980 -0.041775
# Potassium (mg/l)                    0.754484         0.748636 -0.044744
# Nitrate (mg/l)                      0.755246         0.753121 -0.045593
# Phosphate (mg/l)                    0.755006         0.752187 -0.043168
#
#                                 Conductivity (uS/cm)  \
# Colour (TCU)                                0.753990
# Turbidity (NTU)                             0.752617
# pH                                         -0.042363
# Conductivity (uS/cm)                        1.000000
# Total Dissolved Solids (mg/l)               0.748699
# Total Hardness (mg/l as CaCO3)              0.747672
# Aluminium (mg/l)                            0.744483
# Chloride (mg/l)                             0.749396
# Total Iron (mg/l)                           0.754554
# Sodium (mg/l)                               0.751929
# Sulphate (mg/l)                             0.753221
# Zinc (mg/l)                                 0.750440
# Magnesium (mg/l)                            0.749118
# Calcium (mg/l)                              0.752775
# Potassium (mg/l)                            0.749214
# Nitrate (mg/l)                              0.751324
# Phosphate (mg/l)                            0.747222
#
#                                 Total Dissolved Solids (mg/l)  \
# Colour (TCU)                                         0.748718
# Turbidity (NTU)                                      0.755528
# pH                                                  -0.044006
# Conductivity (uS/cm)                                 0.748699
# Total Dissolved Solids (mg/l)                        1.000000
# Total Hardness (mg/l as CaCO3)                       0.745505
# Aluminium (mg/l)                                     0.752255
# Chloride (mg/l)                                      0.754592
# Total Iron (mg/l)                                    0.752543
# Sodium (mg/l)                                        0.750340
# Sulphate (mg/l)                                      0.748560
# Zinc (mg/l)                                          0.750242
# Magnesium (mg/l)                                     0.751867
# Calcium (mg/l)                                       0.750462
# Potassium (mg/l)                                     0.750698
# Nitrate (mg/l)                                       0.743644
# Phosphate (mg/l)                                     0.746325
#
#                                 Total Hardness (mg/l as CaCO3)  \
# Colour (TCU)                                          0.745498
# Turbidity (NTU)                                       0.749558
# pH                                                   -0.044394
# Conductivity (uS/cm)                                  0.747672
# Total Dissolved Solids (mg/l)                         0.745505
# Total Hardness (mg/l as CaCO3)                        1.000000
# Aluminium (mg/l)                                      0.746234
# Chloride (mg/l)                                       0.751529
# Total Iron (mg/l)                                     0.748817
# Sodium (mg/l)                                         0.748920
# Sulphate (mg/l)                                       0.743679
# Zinc (mg/l)                                           0.751788
# Magnesium (mg/l)                                      0.748201
# Calcium (mg/l)                                        0.747218
# Potassium (mg/l)                                      0.747368
# Nitrate (mg/l)                                        0.742780
# Phosphate (mg/l)                                      0.750667
#
#                                 Aluminium (mg/l)  Chloride (mg/l)  \
# Colour (TCU)                            0.750874         0.747499
# Turbidity (NTU)                         0.748596         0.754928
# pH                                     -0.051973        -0.048232
# Conductivity (uS/cm)                    0.744483         0.749396
# Total Dissolved Solids (mg/l)           0.752255         0.754592
# Total Hardness (mg/l as CaCO3)          0.746234         0.751529
# Aluminium (mg/l)                        1.000000         0.751024
# Chloride (mg/l)                         0.751024         1.000000
# Total Iron (mg/l)                       0.746312         0.758243
# Sodium (mg/l)                           0.748090         0.752279
# Sulphate (mg/l)                         0.745120         0.750914
# Zinc (mg/l)                             0.748384         0.757840
# Magnesium (mg/l)                        0.750620         0.754775
# Calcium (mg/l)                          0.747276         0.754510
# Potassium (mg/l)                        0.747976         0.752729
# Nitrate (mg/l)                          0.747962         0.747878
# Phosphate (mg/l)                        0.747161         0.752192
#
#                                 Total Iron (mg/l)  Sodium (mg/l)  \
# Colour (TCU)                             0.756394       0.751185
# Turbidity (NTU)                          0.749736       0.753077
# pH                                      -0.051106      -0.045605
# Conductivity (uS/cm)                     0.754554       0.751929
# Total Dissolved Solids (mg/l)            0.752543       0.750340
# Total Hardness (mg/l as CaCO3)           0.748817       0.748920
# Aluminium (mg/l)                         0.746312       0.748090
# Chloride (mg/l)                          0.758243       0.752279
# Total Iron (mg/l)                        1.000000       0.754617
# Sodium (mg/l)                            0.754617       1.000000
# Sulphate (mg/l)                          0.752593       0.749473
# Zinc (mg/l)                              0.751597       0.751137
# Magnesium (mg/l)                         0.751144       0.747790
# Calcium (mg/l)                           0.755845       0.753694
# Potassium (mg/l)                         0.752737       0.747828
# Nitrate (mg/l)                           0.747048       0.748987
# Phosphate (mg/l)                         0.753177       0.754418
#
#                                 Sulphate (mg/l)  Zinc (mg/l)  \
# Colour (TCU)                           0.750063     0.752901
# Turbidity (NTU)                        0.751699     0.753478
# pH                                    -0.041821    -0.042260
# Conductivity (uS/cm)                   0.753221     0.750440
# Total Dissolved Solids (mg/l)          0.748560     0.750242
# Total Hardness (mg/l as CaCO3)         0.743679     0.751788
# Aluminium (mg/l)                       0.745120     0.748384
# Chloride (mg/l)                        0.750914     0.757840
# Total Iron (mg/l)                      0.752593     0.751597
# Sodium (mg/l)                          0.749473     0.751137
# Sulphate (mg/l)                        1.000000     0.748979
# Zinc (mg/l)                            0.748979     1.000000
# Magnesium (mg/l)                       0.747219     0.750650
# Calcium (mg/l)                         0.748365     0.752095
# Potassium (mg/l)                       0.748103     0.753472
# Nitrate (mg/l)                         0.742555     0.747029
# Phosphate (mg/l)                       0.751016     0.750242
#
#                                 Magnesium (mg/l)  Calcium (mg/l)  \
# Colour (TCU)                            0.750764        0.753162
# Turbidity (NTU)                         0.751698        0.756980
# pH                                     -0.049970       -0.041775
# Conductivity (uS/cm)                    0.749118        0.752775
# Total Dissolved Solids (mg/l)           0.751867        0.750462
# Total Hardness (mg/l as CaCO3)          0.748201        0.747218
# Aluminium (mg/l)                        0.750620        0.747276
# Chloride (mg/l)                         0.754775        0.754510
# Total Iron (mg/l)                       0.751144        0.755845
# Sodium (mg/l)                           0.747790        0.753694
# Sulphate (mg/l)                         0.747219        0.748365
# Zinc (mg/l)                             0.750650        0.752095
# Magnesium (mg/l)                        1.000000        0.744822
# Calcium (mg/l)                          0.744822        1.000000
# Potassium (mg/l)                        0.754380        0.753284
# Nitrate (mg/l)                          0.747267        0.753582
# Phosphate (mg/l)                        0.745715        0.750324
#
#                                 Potassium (mg/l)  Nitrate (mg/l)  \
# Colour (TCU)                            0.754484        0.755246
# Turbidity (NTU)                         0.748636        0.753121
# pH                                     -0.044744       -0.045593
# Conductivity (uS/cm)                    0.749214        0.751324
# Total Dissolved Solids (mg/l)           0.750698        0.743644
# Total Hardness (mg/l as CaCO3)          0.747368        0.742780
# Aluminium (mg/l)                        0.747976        0.747962
# Chloride (mg/l)                         0.752729        0.747878
# Total Iron (mg/l)                       0.752737        0.747048
# Sodium (mg/l)                           0.747828        0.748987
# Sulphate (mg/l)                         0.748103        0.742555
# Zinc (mg/l)                             0.753472        0.747029
# Magnesium (mg/l)                        0.754380        0.747267
# Calcium (mg/l)                          0.753284        0.753582
# Potassium (mg/l)                        1.000000        0.752441
# Nitrate (mg/l)                          0.752441        1.000000
# Phosphate (mg/l)                        0.753119        0.750546
#
#                                 Phosphate (mg/l)
# Colour (TCU)                            0.755006
# Turbidity (NTU)                         0.752187
# pH                                     -0.043168
# Conductivity (uS/cm)                    0.747222
# Total Dissolved Solids (mg/l)           0.746325
# Total Hardness (mg/l as CaCO3)          0.750667
# Aluminium (mg/l)                        0.747161
# Chloride (mg/l)                         0.752192
# Total Iron (mg/l)                       0.753177
# Sodium (mg/l)                           0.754418
# Sulphate (mg/l)                         0.751016
# Zinc (mg/l)                             0.750242
# Magnesium (mg/l)                        0.745715
# Calcium (mg/l)                          0.750324
# Potassium (mg/l)                        0.753119
# Nitrate (mg/l)                          0.750546
# Phosphate (mg/l)                        1.000000

# %%
f = plt.figure()
ax1 = f.add_subplot(221)
ax1.boxplot(df['Colour (TCU)'])
ax2 = f.add_subplot(222)
ax2.boxplot(df['Turbidity (NTU)'])
ax3 = f.add_subplot(223)
ax3.boxplot(df['pH'])
ax4 = f.add_subplot(224)
ax4.boxplot(df['Conductivity (uS/cm)'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x210fb25ad60>,
#   <matplotlib.lines.Line2D at 0x210fb269070>],
#  'caps': [<matplotlib.lines.Line2D at 0x210fb269340>,
#   <matplotlib.lines.Line2D at 0x210fb269610>],
#  'boxes': [<matplotlib.lines.Line2D at 0x210fb25aa90>],
#  'medians': [<matplotlib.lines.Line2D at 0x210fb2698e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x210fb269bb0>],
#  'means': []}

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %%
df.pH.value_counts()
# Out:
# 6.67     42
# 7.45     39
# 7.70     39
# 7.87     35
# 8.24     35
#          ..
# 1.80      1
# 13.36     1
# 13.62     1
# 4.17      1
# 6.24      1
# Name: pH, Length: 1375, dtype: int64

# %%
plt.boxplot(df['pH'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x210fcd563d0>,
#   <matplotlib.lines.Line2D at 0x210fcd566a0>],
#  'caps': [<matplotlib.lines.Line2D at 0x210fcd56970>,
#   <matplotlib.lines.Line2D at 0x210fcd56c40>],
#  'boxes': [<matplotlib.lines.Line2D at 0x210fcd560d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x210fcd56f10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x210fcd4b220>],
#  'means': []}

# %%
df.describe()
# Out:
#        Colour (TCU)  Turbidity (NTU)            pH  Conductivity (uS/cm)  \
# count  10000.000000     10000.000000  10000.000000          10000.000000
# mean      15.006526         5.003388      7.337763           1502.148272
# std        8.717615         2.906118      3.101412            869.812955
# min        0.010000         0.000000      0.000000              0.120000
# 25%        7.517500         2.490000      6.397500            741.635000
# 50%       15.000000         5.000000      7.470000           1500.095000
# 75%       22.660000         7.530000      8.480000           2259.740000
# max       30.000000        10.000000     14.000000           2999.910000
#
#        Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# count                   10000.000000                    10000.000000
# mean                     1001.183584                      300.613398
# std                       578.522848                      171.478482
# min                         0.050000                        0.030000
# 25%                       494.590000                      154.980000
# 50%                      1000.030000                      300.005000
# 75%                      1497.880000                      448.605000
# max                      1999.960000                      599.970000
#
#        Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# count      10000.000000     10000.000000       10000.000000   10000.000000
# mean           0.200808       249.491721           0.300165     200.793553
# std            0.115359       144.526095           0.174572     116.039382
# min            0.000000         0.000000           0.000000       0.010000
# 25%            0.100000       122.707500           0.150000      99.890000
# 50%            0.200000       249.915000           0.300000     199.995000
# 75%            0.300000       374.760000           0.450000     303.645000
# max            0.400000       499.870000           0.600000     399.980000
#
#        Sulphate (mg/l)   Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# count     10000.000000  10000.000000      10000.000000    10000.000000
# mean        402.124054      5.004608        100.026299      149.944522
# std         230.187867      2.897890         57.979525       87.162086
# min           0.030000      0.000000          0.030000        0.020000
# 25%         205.910000      2.460000         49.362500       74.417500
# 50%         400.125000      5.000000        100.015000      150.010000
# 75%         601.925000      7.500000        150.130000      226.245000
# max         799.880000     10.000000        199.980000      299.970000
#
#        Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)    Potability
# count      10000.000000    10000.000000      10000.000000  10000.000000
# mean          49.838229       45.162176          2.205561      0.500000
# std           28.795520       25.861234          1.274395      0.500025
# min            0.000000        0.030000          0.000000      0.000000
# 25%           24.490000       23.150000          1.090000      0.000000
# 50%           49.990000       45.010000          2.200000      0.500000
# 75%           75.040000       67.772500          3.320000      1.000000
# max          100.000000       90.000000          4.400000      1.000000

# %%
from scipy import stats
def detect_outliers(dataset, columns):
    df = dataset.copy()
    df[columns] = stats.zscore(df[columns])
    outliers = df[(df[columns] < -3) | (df[columns] > 3)]
    print(f"The number of outliers: {outliers.shape[0]}")
    df = df[(df[columns] > -3) & (df[columns] < 3)].reset_index(drop=True)
    return df

# %%
detect_outliers(df,'pH')
# Out:
# The number of outliers: 0
#       Colour (TCU)  Turbidity (NTU)        pH  Conductivity (uS/cm)  \
# 0            11.13             4.21 -0.234667                682.05
# 1            10.24             4.73  0.345743               1464.38
# 2             5.27             2.91  0.187742                749.81
# 3            29.13             7.75  1.593624               1833.20
# 4            19.17             5.90  0.568233               2548.94
# ...            ...              ...       ...                   ...
# 9995         23.39             9.99  0.710111               2403.83
# 9996         29.47             8.56 -2.262877               2568.26
# 9997         21.95             8.52  1.748400               1566.61
# 9998          9.90             4.24 -0.066993               1276.29
# 9999         25.39             6.44 -2.214510               1829.89
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                            716.92                           66.83
# 1                            168.89                          162.70
# 2                            268.09                           90.33
# 3                           1269.14                          532.66
# 4                           1652.02                          562.66
# ...                             ...                             ...
# 9995                        1433.72                          551.77
# 9996                        1103.98                          557.54
# 9997                        1620.49                          386.69
# 9998                          26.05                          175.44
# 9999                        1810.41                          445.73
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0                 0.14           201.10               0.27         134.10
# 1                 0.12           196.70               0.10          10.64
# 2                 0.11            30.88               0.10          28.39
# 3                 0.23           352.95               0.56         382.94
# 4                 0.21           410.96               0.40         235.47
# ...                ...              ...                ...            ...
# 9995              0.34           337.49               0.41         245.95
# 9996              0.23           327.74               0.30         368.13
# 9997              0.22           465.08               0.30         332.26
# 9998              0.06           195.02               0.00          12.60
# 9999              0.37           305.83               0.49         223.14
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0              225.08         2.37             53.94           29.83
# 1              314.28         2.50             24.62           96.52
# 2              163.42         2.25             73.47          101.56
# 3              623.94         7.84            184.97          285.43
# 4              556.49         7.34            157.91          164.50
# ...               ...          ...               ...             ...
# 9995           669.10         6.56            100.49          215.89
# 9996           406.73         8.84            165.02          220.37
# 9997           734.80         9.24            179.13          184.41
# 9998           132.61         1.71             41.61            0.33
# 9999           510.21         5.01            124.90          160.11
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)  Potability
# 0                 2.70           27.95              0.26           1
# 1                39.38           19.27              0.96           1
# 2                 2.54            7.89              0.48           1
# 3                90.21           79.12              3.21           0
# 4                84.42           77.07              4.17           0
# ...                ...             ...               ...         ...
# 9995             82.84           52.24              2.75           0
# 9996             55.39           65.62              3.82           0
# 9997             81.79           47.52              2.70           0
# 9998             35.22            3.78              0.28           1
# 9999             57.96           84.05              3.24           0
#
# [10000 rows x 18 columns]

# %%
df = df.sample(frac = 1)
df
# Out:
#       Colour (TCU)  Turbidity (NTU)     pH  Conductivity (uS/cm)  \
# 3829         11.13             4.21   6.61                682.05
# 3969         10.24             4.73   8.41               1464.38
# 1272          5.27             2.91   7.92                749.81
# 5134         29.13             7.75  12.28               1833.20
# 9104         19.17             5.90   9.10               2548.94
# ...            ...              ...    ...                   ...
# 5094         23.39             9.99   9.54               2403.83
# 7411         29.47             8.56   0.32               2568.26
# 8527         21.95             8.52  12.76               1566.61
# 2378          9.90             4.24   7.13               1276.29
# 6424         25.39             6.44   0.47               1829.89
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 3829                         716.92                           66.83
# 3969                         168.89                          162.70
# 1272                         268.09                           90.33
# 5134                        1269.14                          532.66
# 9104                        1652.02                          562.66
# ...                             ...                             ...
# 5094                        1433.72                          551.77
# 7411                        1103.98                          557.54
# 8527                        1620.49                          386.69
# 2378                          26.05                          175.44
# 6424                        1810.41                          445.73
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 3829              0.14           201.10               0.27         134.10
# 3969              0.12           196.70               0.10          10.64
# 1272              0.11            30.88               0.10          28.39
# 5134              0.23           352.95               0.56         382.94
# 9104              0.21           410.96               0.40         235.47
# ...                ...              ...                ...            ...
# 5094              0.34           337.49               0.41         245.95
# 7411              0.23           327.74               0.30         368.13
# 8527              0.22           465.08               0.30         332.26
# 2378              0.06           195.02               0.00          12.60
# 6424              0.37           305.83               0.49         223.14
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 3829           225.08         2.37             53.94           29.83
# 3969           314.28         2.50             24.62           96.52
# 1272           163.42         2.25             73.47          101.56
# 5134           623.94         7.84            184.97          285.43
# 9104           556.49         7.34            157.91          164.50
# ...               ...          ...               ...             ...
# 5094           669.10         6.56            100.49          215.89
# 7411           406.73         8.84            165.02          220.37
# 8527           734.80         9.24            179.13          184.41
# 2378           132.61         1.71             41.61            0.33
# 6424           510.21         5.01            124.90          160.11
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)   Potability
# 3829              2.70           27.95              0.26      potable
# 3969             39.38           19.27              0.96      potable
# 1272              2.54            7.89              0.48      potable
# 5134             90.21           79.12              3.21  non-potable
# 9104             84.42           77.07              4.17  non-potable
# ...                ...             ...               ...          ...
# 5094             82.84           52.24              2.75  non-potable
# 7411             55.39           65.62              3.82  non-potable
# 8527             81.79           47.52              2.70  non-potable
# 2378             35.22            3.78              0.28      potable
# 6424             57.96           84.05              3.24  non-potable
#
# [10000 rows x 18 columns]

# %%
df = df.reset_index()
df = df.drop(columns=['index'])
df
# Out:
#       Colour (TCU)  Turbidity (NTU)     pH  Conductivity (uS/cm)  \
# 0            11.13             4.21   6.61                682.05
# 1            10.24             4.73   8.41               1464.38
# 2             5.27             2.91   7.92                749.81
# 3            29.13             7.75  12.28               1833.20
# 4            19.17             5.90   9.10               2548.94
# ...            ...              ...    ...                   ...
# 9995         23.39             9.99   9.54               2403.83
# 9996         29.47             8.56   0.32               2568.26
# 9997         21.95             8.52  12.76               1566.61
# 9998          9.90             4.24   7.13               1276.29
# 9999         25.39             6.44   0.47               1829.89
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                            716.92                           66.83
# 1                            168.89                          162.70
# 2                            268.09                           90.33
# 3                           1269.14                          532.66
# 4                           1652.02                          562.66
# ...                             ...                             ...
# 9995                        1433.72                          551.77
# 9996                        1103.98                          557.54
# 9997                        1620.49                          386.69
# 9998                          26.05                          175.44
# 9999                        1810.41                          445.73
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0                 0.14           201.10               0.27         134.10
# 1                 0.12           196.70               0.10          10.64
# 2                 0.11            30.88               0.10          28.39
# 3                 0.23           352.95               0.56         382.94
# 4                 0.21           410.96               0.40         235.47
# ...                ...              ...                ...            ...
# 9995              0.34           337.49               0.41         245.95
# 9996              0.23           327.74               0.30         368.13
# 9997              0.22           465.08               0.30         332.26
# 9998              0.06           195.02               0.00          12.60
# 9999              0.37           305.83               0.49         223.14
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0              225.08         2.37             53.94           29.83
# 1              314.28         2.50             24.62           96.52
# 2              163.42         2.25             73.47          101.56
# 3              623.94         7.84            184.97          285.43
# 4              556.49         7.34            157.91          164.50
# ...               ...          ...               ...             ...
# 9995           669.10         6.56            100.49          215.89
# 9996           406.73         8.84            165.02          220.37
# 9997           734.80         9.24            179.13          184.41
# 9998           132.61         1.71             41.61            0.33
# 9999           510.21         5.01            124.90          160.11
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)   Potability
# 0                 2.70           27.95              0.26      potable
# 1                39.38           19.27              0.96      potable
# 2                 2.54            7.89              0.48      potable
# 3                90.21           79.12              3.21  non-potable
# 4                84.42           77.07              4.17  non-potable
# ...                ...             ...               ...          ...
# 9995             82.84           52.24              2.75  non-potable
# 9996             55.39           65.62              3.82  non-potable
# 9997             81.79           47.52              2.70  non-potable
# 9998             35.22            3.78              0.28      potable
# 9999             57.96           84.05              3.24  non-potable
#
# [10000 rows x 18 columns]

# %%
from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()

# %%
df['Potability'] = enc.fit_transform(df['Potability'])

# %%
y = df.iloc[:,-1]

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    1
# 9999    0
# Name: Potability, Length: 10000, dtype: int32

# %%
x = df.iloc[:,:-1]

# %%
x
# Out:
#       Colour (TCU)  Turbidity (NTU)     pH  Conductivity (uS/cm)  \
# 0            11.13             4.21   6.61                682.05
# 1            10.24             4.73   8.41               1464.38
# 2             5.27             2.91   7.92                749.81
# 3            29.13             7.75  12.28               1833.20
# 4            19.17             5.90   9.10               2548.94
# ...            ...              ...    ...                   ...
# 9995         23.39             9.99   9.54               2403.83
# 9996         29.47             8.56   0.32               2568.26
# 9997         21.95             8.52  12.76               1566.61
# 9998          9.90             4.24   7.13               1276.29
# 9999         25.39             6.44   0.47               1829.89
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                            716.92                           66.83
# 1                            168.89                          162.70
# 2                            268.09                           90.33
# 3                           1269.14                          532.66
# 4                           1652.02                          562.66
# ...                             ...                             ...
# 9995                        1433.72                          551.77
# 9996                        1103.98                          557.54
# 9997                        1620.49                          386.69
# 9998                          26.05                          175.44
# 9999                        1810.41                          445.73
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0                 0.14           201.10               0.27         134.10
# 1                 0.12           196.70               0.10          10.64
# 2                 0.11            30.88               0.10          28.39
# 3                 0.23           352.95               0.56         382.94
# 4                 0.21           410.96               0.40         235.47
# ...                ...              ...                ...            ...
# 9995              0.34           337.49               0.41         245.95
# 9996              0.23           327.74               0.30         368.13
# 9997              0.22           465.08               0.30         332.26
# 9998              0.06           195.02               0.00          12.60
# 9999              0.37           305.83               0.49         223.14
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0              225.08         2.37             53.94           29.83
# 1              314.28         2.50             24.62           96.52
# 2              163.42         2.25             73.47          101.56
# 3              623.94         7.84            184.97          285.43
# 4              556.49         7.34            157.91          164.50
# ...               ...          ...               ...             ...
# 9995           669.10         6.56            100.49          215.89
# 9996           406.73         8.84            165.02          220.37
# 9997           734.80         9.24            179.13          184.41
# 9998           132.61         1.71             41.61            0.33
# 9999           510.21         5.01            124.90          160.11
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)
# 0                 2.70           27.95              0.26
# 1                39.38           19.27              0.96
# 2                 2.54            7.89              0.48
# 3                90.21           79.12              3.21
# 4                84.42           77.07              4.17
# ...                ...             ...               ...
# 9995             82.84           52.24              2.75
# 9996             55.39           65.62              3.82
# 9997             81.79           47.52              2.70
# 9998             35.22            3.78              0.28
# 9999             57.96           84.05              3.24
#
# [10000 rows x 17 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression

# %%
reg = LogisticRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = reg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.9956666666666667

# %%
from sklearn.metrics import precision_score,classification_report

# %%
precision_score(y_pred,y_test)
# Out:
# 0.9939879759519038

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1499,    4],
#        [   9, 1488]], dtype=int64)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dtc.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9996666666666667

# %%
dtc.score(x_train,y_train)
# Out:
# 1.0

# %%
dtc.score(x_test,y_test)
# Out:
# 0.9996666666666667

# %%
precision_score(y_test,y_pred)
# Out:
# 0.9993324432576769

# %%
report1 = classification_report(y_pred, y_test, digits=4)

# %%
print(report1)
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9993    1.0000    0.9997      1502
#            1     1.0000    0.9993    0.9997      1498
#
#     accuracy                         0.9997      3000
#    macro avg     0.9997    0.9997    0.9997      3000
# weighted avg     0.9997    0.9997    0.9997      3000

# %%
from sklearn.model_selection import learning_curve
import numpy as np

# %%
train_sizes, train_scores, valid_scores = learning_curve(
dtc, x, y, train_sizes=np.linspace(0.05, 1.0, 30), cv=5,
)
train_mean = np.mean(train_scores,axis=1)
test_mean = np.mean(valid_scores,axis=1)
plt.subplots(1,figsize=(10,10))
plt.plot(train_sizes, train_mean, "r-+", linewidth=2, label="train")
plt.plot(train_sizes, test_mean, "b-", linewidth=3, label="valid")
plt.legend()

plt.show()
