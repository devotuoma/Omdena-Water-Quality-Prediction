# %%
import pandas as pd

# %%
df = pd.read_csv('Synthetic_Data_Water_Quality.csv')

# %%
df
# Out:
#       Colour (TCU)  Turbidity (NTU)    pH  Conductivity (uS/cm)  \
# 0             8.34             3.39  8.06                819.00
# 1            14.45             3.36  8.28               1371.10
# 2             3.87             4.23  6.86                202.75
# 3            14.57             1.75  7.00                696.16
# 4             9.01             2.20  6.73                129.24
# ...            ...              ...   ...                   ...
# 9995         27.64             9.46  0.09               2422.27
# 9996         25.58             8.61  4.39               1516.78
# 9997         19.40             8.16  3.05               2456.68
# 9998         18.73             5.03  9.35               1900.45
# 9999         27.30             8.66  9.22               2750.24
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                            787.15                          279.89
# 1                            779.66                          112.04
# 2                            485.10                          113.17
# 3                            409.71                          140.39
# 4                            343.55                            6.52
# ...                             ...                             ...
# 9995                        1147.04                          521.18
# 9996                        1604.78                          429.84
# 9997                        1439.54                          483.23
# 9998                        1092.84                          458.86
# 9999                        1058.46                          492.12
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0                 0.09           129.30               0.22          13.13
# 1                 0.20           163.73               0.13         127.48
# 2                 0.15            66.68               0.29         142.97
# 3                 0.06           102.42               0.15         194.07
# 4                 0.07           140.47               0.28           3.77
# ...                ...              ...                ...            ...
# 9995              0.24           362.50               0.41         283.40
# 9996              0.33           394.23               0.55         303.78
# 9997              0.40           348.95               0.48         229.37
# 9998              0.28           289.98               0.52         310.67
# 9999              0.35           283.16               0.59         247.13
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0               81.01         2.24             12.69          107.95
# 1              307.99         4.05             52.01          107.12
# 2               16.70         0.86             88.47          127.47
# 3              393.09         2.60             61.36           99.16
# 4              170.65         0.04             47.22          107.17
# ...               ...          ...               ...             ...
# 9995           438.94         9.88            112.00          258.93
# 9996           556.85         8.87            122.23          284.79
# 9997           690.85         6.67            136.61          198.87
# 9998           564.05         7.22            108.37          260.68
# 9999           423.96         8.42            149.07          266.26
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)   Potability
# 0                17.50           22.23              0.41      potable
# 1                45.28           16.06              0.68      potable
# 2                 4.90           19.81              0.91      potable
# 3                36.73           42.82              0.02      potable
# 4                44.79           14.35              2.08      potable
# ...                ...             ...               ...          ...
# 9995             70.92           81.10              3.09  non-potable
# 9996             76.31           79.69              2.48  non-potable
# 9997             68.99           53.38              3.37  non-potable
# 9998             82.73           83.58              2.78  non-potable
# 9999             87.11           51.96              4.11  non-potable
#
# [10000 rows x 18 columns]

# %%
df = df.sample(frac=1)

# %%
df
# Out:
#       Colour (TCU)  Turbidity (NTU)     pH  Conductivity (uS/cm)  \
# 8329         25.64             5.74   5.00               1782.74
# 9194         16.61             9.22  11.56               2377.82
# 1207         14.40             1.38   6.76                656.75
# 3196          6.24             3.83   7.33                468.98
# 4833         11.10             0.62   6.77                667.87
# ...            ...              ...    ...                   ...
# 1174         12.29             3.65   7.30               1275.35
# 8764         29.90             5.90   0.74               2657.51
# 1022          4.13             2.44   7.90                697.55
# 8614         22.69             5.28   2.22               2273.87
# 7395         21.41             5.02   9.25               1781.15
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 8329                        1646.63                          459.42
# 9194                        1356.71                          473.89
# 1207                         645.51                          271.57
# 3196                         602.06                            1.39
# 4833                          15.63                           20.77
# ...                             ...                             ...
# 1174                         552.38                           40.27
# 8764                        1378.30                          370.07
# 1022                         825.41                          245.40
# 8614                        1606.16                          471.20
# 7395                        1552.79                          522.23
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 8329              0.34           291.20               0.50         204.48
# 9194              0.29           441.60               0.38         324.94
# 1207              0.10           175.75               0.20         109.39
# 3196              0.20            53.89               0.16          34.96
# 4833              0.04           105.46               0.13          82.78
# ...                ...              ...                ...            ...
# 1174              0.14           164.52               0.28         126.30
# 8764              0.32           258.56               0.45         394.93
# 1022              0.13            33.60               0.17         120.39
# 8614              0.21           448.21               0.33         374.56
# 7395              0.24           442.71               0.47         300.24
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 8329           778.75         7.24            184.12          284.22
# 9194           622.92         6.13            157.13          214.69
# 1207           389.46         3.42             54.76          126.21
# 3196           237.23         4.76              3.05          127.06
# 4833           195.94         4.71             83.24           54.71
# ...               ...          ...               ...             ...
# 1174            92.84         1.68              9.30           51.54
# 8764           561.45         9.67            115.56          169.62
# 1022           259.12         3.44             85.68           19.84
# 8614           454.97         5.45            188.85          169.03
# 7395           699.73         9.36            196.19          229.82
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)   Potability
# 8329             70.97           89.72              3.01  non-potable
# 9194             66.35           74.61              3.58  non-potable
# 1207             32.40           21.17              0.84      potable
# 3196             28.69            6.14              1.99      potable
# 4833             33.73           29.32              0.06      potable
# ...                ...             ...               ...          ...
# 1174             44.84           11.34              1.27      potable
# 8764             71.34           72.16              2.99  non-potable
# 1022             20.24           15.90              0.82      potable
# 8614             90.34           58.67              3.75  non-potable
# 7395             84.87           64.71              4.40  non-potable
#
# [10000 rows x 18 columns]

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       index  Colour (TCU)  Turbidity (NTU)     pH  Conductivity (uS/cm)  \
# 0      8329         25.64             5.74   5.00               1782.74
# 1      9194         16.61             9.22  11.56               2377.82
# 2      1207         14.40             1.38   6.76                656.75
# 3      3196          6.24             3.83   7.33                468.98
# 4      4833         11.10             0.62   6.77                667.87
# ...     ...           ...              ...    ...                   ...
# 9995   1174         12.29             3.65   7.30               1275.35
# 9996   8764         29.90             5.90   0.74               2657.51
# 9997   1022          4.13             2.44   7.90                697.55
# 9998   8614         22.69             5.28   2.22               2273.87
# 9999   7395         21.41             5.02   9.25               1781.15
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                           1646.63                          459.42
# 1                           1356.71                          473.89
# 2                            645.51                          271.57
# 3                            602.06                            1.39
# 4                             15.63                           20.77
# ...                             ...                             ...
# 9995                         552.38                           40.27
# 9996                        1378.30                          370.07
# 9997                         825.41                          245.40
# 9998                        1606.16                          471.20
# 9999                        1552.79                          522.23
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0                 0.34           291.20               0.50         204.48
# 1                 0.29           441.60               0.38         324.94
# 2                 0.10           175.75               0.20         109.39
# 3                 0.20            53.89               0.16          34.96
# 4                 0.04           105.46               0.13          82.78
# ...                ...              ...                ...            ...
# 9995              0.14           164.52               0.28         126.30
# 9996              0.32           258.56               0.45         394.93
# 9997              0.13            33.60               0.17         120.39
# 9998              0.21           448.21               0.33         374.56
# 9999              0.24           442.71               0.47         300.24
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0              778.75         7.24            184.12          284.22
# 1              622.92         6.13            157.13          214.69
# 2              389.46         3.42             54.76          126.21
# 3              237.23         4.76              3.05          127.06
# 4              195.94         4.71             83.24           54.71
# ...               ...          ...               ...             ...
# 9995            92.84         1.68              9.30           51.54
# 9996           561.45         9.67            115.56          169.62
# 9997           259.12         3.44             85.68           19.84
# 9998           454.97         5.45            188.85          169.03
# 9999           699.73         9.36            196.19          229.82
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)   Potability
# 0                70.97           89.72              3.01  non-potable
# 1                66.35           74.61              3.58  non-potable
# 2                32.40           21.17              0.84      potable
# 3                28.69            6.14              1.99      potable
# 4                33.73           29.32              0.06      potable
# ...                ...             ...               ...          ...
# 9995             44.84           11.34              1.27      potable
# 9996             71.34           72.16              2.99  non-potable
# 9997             20.24           15.90              0.82      potable
# 9998             90.34           58.67              3.75  non-potable
# 9999             84.87           64.71              4.40  non-potable
#
# [10000 rows x 19 columns]

# %%
df = df.drop(columns=['index'])

# %%
df
# Out:
#       Colour (TCU)  Turbidity (NTU)     pH  Conductivity (uS/cm)  \
# 0            25.64             5.74   5.00               1782.74
# 1            16.61             9.22  11.56               2377.82
# 2            14.40             1.38   6.76                656.75
# 3             6.24             3.83   7.33                468.98
# 4            11.10             0.62   6.77                667.87
# ...            ...              ...    ...                   ...
# 9995         12.29             3.65   7.30               1275.35
# 9996         29.90             5.90   0.74               2657.51
# 9997          4.13             2.44   7.90                697.55
# 9998         22.69             5.28   2.22               2273.87
# 9999         21.41             5.02   9.25               1781.15
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                           1646.63                          459.42
# 1                           1356.71                          473.89
# 2                            645.51                          271.57
# 3                            602.06                            1.39
# 4                             15.63                           20.77
# ...                             ...                             ...
# 9995                         552.38                           40.27
# 9996                        1378.30                          370.07
# 9997                         825.41                          245.40
# 9998                        1606.16                          471.20
# 9999                        1552.79                          522.23
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0                 0.34           291.20               0.50         204.48
# 1                 0.29           441.60               0.38         324.94
# 2                 0.10           175.75               0.20         109.39
# 3                 0.20            53.89               0.16          34.96
# 4                 0.04           105.46               0.13          82.78
# ...                ...              ...                ...            ...
# 9995              0.14           164.52               0.28         126.30
# 9996              0.32           258.56               0.45         394.93
# 9997              0.13            33.60               0.17         120.39
# 9998              0.21           448.21               0.33         374.56
# 9999              0.24           442.71               0.47         300.24
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0              778.75         7.24            184.12          284.22
# 1              622.92         6.13            157.13          214.69
# 2              389.46         3.42             54.76          126.21
# 3              237.23         4.76              3.05          127.06
# 4              195.94         4.71             83.24           54.71
# ...               ...          ...               ...             ...
# 9995            92.84         1.68              9.30           51.54
# 9996           561.45         9.67            115.56          169.62
# 9997           259.12         3.44             85.68           19.84
# 9998           454.97         5.45            188.85          169.03
# 9999           699.73         9.36            196.19          229.82
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)   Potability
# 0                70.97           89.72              3.01  non-potable
# 1                66.35           74.61              3.58  non-potable
# 2                32.40           21.17              0.84      potable
# 3                28.69            6.14              1.99      potable
# 4                33.73           29.32              0.06      potable
# ...                ...             ...               ...          ...
# 9995             44.84           11.34              1.27      potable
# 9996             71.34           72.16              2.99  non-potable
# 9997             20.24           15.90              0.82      potable
# 9998             90.34           58.67              3.75  non-potable
# 9999             84.87           64.71              4.40  non-potable
#
# [10000 rows x 18 columns]

# %%
df1 = pd.read_csv('water_potability.csv')

# %%
df1
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# 1       592.885359       15.180013        56.329076   4.500656           0
# 2       418.606213       16.868637        66.420093   3.055934           0
# 3       363.266516       18.436524       100.341674   4.628771           0
# 4       398.410813       11.558279        31.997993   4.075075           0
# ...            ...             ...              ...        ...         ...
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1
#
# [3276 rows x 10 columns]

# %%
df1 = df1.dropna()

# %%
df1
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 3      8.316766  214.373394  22018.417441     8.059332  356.886136
# 4      9.092223  181.101509  17978.986339     6.546600  310.135738
# 5      5.584087  188.313324  28748.687739     7.544869  326.678363
# 6     10.223862  248.071735  28749.716544     7.513408  393.663396
# 7      8.635849  203.361523  13672.091764     4.563009  303.309771
# ...         ...         ...           ...          ...         ...
# 3267   8.989900  215.047358  15921.412018     6.297312  312.931022
# 3268   6.702547  207.321086  17246.920347     7.708117  304.510230
# 3269  11.491011   94.812545  37188.826022     9.263166  258.930600
# 3270   6.069616  186.659040  26138.780191     7.747547  345.700257
# 3271   4.668102  193.681735  47580.991603     7.166639  359.948574
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3       363.266516       18.436524       100.341674   4.628771           0
# 4       398.410813       11.558279        31.997993   4.075075           0
# 5       280.467916        8.399735        54.917862   2.559708           0
# 6       283.651634       13.789695        84.603556   2.672989           0
# 7       474.607645       12.363817        62.798309   4.401425           0
# ...            ...             ...              ...        ...         ...
# 3267    390.410231        9.899115        55.069304   4.613843           1
# 3268    329.266002       16.217303        28.878601   3.442983           1
# 3269    439.893618       16.172755        41.558501   4.369264           1
# 3270    415.886955       12.067620        60.419921   3.669712           1
# 3271    526.424171       13.894419        66.687695   4.435821           1
#
# [2011 rows x 10 columns]

# %%
mapping = {1: 'non-potable', 0: 'potable'}

# Applying the mapping using replace
df1['Potability'] = df1['Potability'].replace(mapping)
# Out:
# C:\Users\bibhz\AppData\Local\Temp\ipykernel_10124\443615161.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Potability'] = df1['Potability'].replace(mapping)

# %%
df1.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Colour (TCU)', 'Turbidity (NTU)', 'pH', 'Conductivity (uS/cm)',
#        'Total Dissolved Solids (mg/l)', 'Total Hardness (mg/l as CaCO3)',
#        'Aluminium (mg/l)', 'Chloride (mg/l)', 'Total Iron (mg/l)',
#        'Sodium (mg/l)', 'Sulphate (mg/l)', 'Zinc (mg/l)', 'Magnesium (mg/l)',
#        'Calcium (mg/l)', 'Potassium (mg/l)', 'Nitrate (mg/l)',
#        'Phosphate (mg/l)', 'Potability'],
#       dtype='object')

# %%
df1 = df1.rename(columns={'ph':'pH','Hardness':'Total Hardness (mg/l as CaCO3)','Sulfate':'Sulphate (mg/l)','Conductivity':'Conductivity (uS/cm)'})

# %%
df1
# Out:
#              pH  Total Hardness (mg/l as CaCO3)        Solids  Chloramines  \
# 3      8.316766                      214.373394  22018.417441     8.059332
# 4      9.092223                      181.101509  17978.986339     6.546600
# 5      5.584087                      188.313324  28748.687739     7.544869
# 6     10.223862                      248.071735  28749.716544     7.513408
# 7      8.635849                      203.361523  13672.091764     4.563009
# ...         ...                             ...           ...          ...
# 3267   8.989900                      215.047358  15921.412018     6.297312
# 3268   6.702547                      207.321086  17246.920347     7.708117
# 3269  11.491011                       94.812545  37188.826022     9.263166
# 3270   6.069616                      186.659040  26138.780191     7.747547
# 3271   4.668102                      193.681735  47580.991603     7.166639
#
#       Sulphate (mg/l)  Conductivity (uS/cm)  Organic_carbon  Trihalomethanes  \
# 3          356.886136            363.266516       18.436524       100.341674
# 4          310.135738            398.410813       11.558279        31.997993
# 5          326.678363            280.467916        8.399735        54.917862
# 6          393.663396            283.651634       13.789695        84.603556
# 7          303.309771            474.607645       12.363817        62.798309
# ...               ...                   ...             ...              ...
# 3267       312.931022            390.410231        9.899115        55.069304
# 3268       304.510230            329.266002       16.217303        28.878601
# 3269       258.930600            439.893618       16.172755        41.558501
# 3270       345.700257            415.886955       12.067620        60.419921
# 3271       359.948574            526.424171       13.894419        66.687695
#
#       Turbidity   Potability
# 3      4.628771      potable
# 4      4.075075      potable
# 5      2.559708      potable
# 6      2.672989      potable
# 7      4.401425      potable
# ...         ...          ...
# 3267   4.613843  non-potable
# 3268   3.442983  non-potable
# 3269   4.369264  non-potable
# 3270   3.669712  non-potable
# 3271   4.435821  non-potable
#
# [2011 rows x 10 columns]

# %%
df1 = df1.drop(columns=['Solids','Chloramines','Organic_carbon','Trihalomethanes','Turbidity'])

# %%
df1
# Out:
#              pH  Total Hardness (mg/l as CaCO3)  Sulphate (mg/l)  \
# 3      8.316766                      214.373394       356.886136
# 4      9.092223                      181.101509       310.135738
# 5      5.584087                      188.313324       326.678363
# 6     10.223862                      248.071735       393.663396
# 7      8.635849                      203.361523       303.309771
# ...         ...                             ...              ...
# 3267   8.989900                      215.047358       312.931022
# 3268   6.702547                      207.321086       304.510230
# 3269  11.491011                       94.812545       258.930600
# 3270   6.069616                      186.659040       345.700257
# 3271   4.668102                      193.681735       359.948574
#
#       Conductivity (uS/cm)   Potability
# 3               363.266516      potable
# 4               398.410813      potable
# 5               280.467916      potable
# 6               283.651634      potable
# 7               474.607645      potable
# ...                    ...          ...
# 3267            390.410231  non-potable
# 3268            329.266002  non-potable
# 3269            439.893618  non-potable
# 3270            415.886955  non-potable
# 3271            526.424171  non-potable
#
# [2011 rows x 5 columns]

# %%
df
# Out:
#       Colour (TCU)  Turbidity (NTU)     pH  Conductivity (uS/cm)  \
# 0            25.64             5.74   5.00               1782.74
# 1            16.61             9.22  11.56               2377.82
# 2            14.40             1.38   6.76                656.75
# 3             6.24             3.83   7.33                468.98
# 4            11.10             0.62   6.77                667.87
# ...            ...              ...    ...                   ...
# 9995         12.29             3.65   7.30               1275.35
# 9996         29.90             5.90   0.74               2657.51
# 9997          4.13             2.44   7.90                697.55
# 9998         22.69             5.28   2.22               2273.87
# 9999         21.41             5.02   9.25               1781.15
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                           1646.63                          459.42
# 1                           1356.71                          473.89
# 2                            645.51                          271.57
# 3                            602.06                            1.39
# 4                             15.63                           20.77
# ...                             ...                             ...
# 9995                         552.38                           40.27
# 9996                        1378.30                          370.07
# 9997                         825.41                          245.40
# 9998                        1606.16                          471.20
# 9999                        1552.79                          522.23
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0                 0.34           291.20               0.50         204.48
# 1                 0.29           441.60               0.38         324.94
# 2                 0.10           175.75               0.20         109.39
# 3                 0.20            53.89               0.16          34.96
# 4                 0.04           105.46               0.13          82.78
# ...                ...              ...                ...            ...
# 9995              0.14           164.52               0.28         126.30
# 9996              0.32           258.56               0.45         394.93
# 9997              0.13            33.60               0.17         120.39
# 9998              0.21           448.21               0.33         374.56
# 9999              0.24           442.71               0.47         300.24
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0              778.75         7.24            184.12          284.22
# 1              622.92         6.13            157.13          214.69
# 2              389.46         3.42             54.76          126.21
# 3              237.23         4.76              3.05          127.06
# 4              195.94         4.71             83.24           54.71
# ...               ...          ...               ...             ...
# 9995            92.84         1.68              9.30           51.54
# 9996           561.45         9.67            115.56          169.62
# 9997           259.12         3.44             85.68           19.84
# 9998           454.97         5.45            188.85          169.03
# 9999           699.73         9.36            196.19          229.82
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)   Potability
# 0                70.97           89.72              3.01  non-potable
# 1                66.35           74.61              3.58  non-potable
# 2                32.40           21.17              0.84      potable
# 3                28.69            6.14              1.99      potable
# 4                33.73           29.32              0.06      potable
# ...                ...             ...               ...          ...
# 9995             44.84           11.34              1.27      potable
# 9996             71.34           72.16              2.99  non-potable
# 9997             20.24           15.90              0.82      potable
# 9998             90.34           58.67              3.75  non-potable
# 9999             84.87           64.71              4.40  non-potable
#
# [10000 rows x 18 columns]

# %%
df[['Potability']].value_counts()
# Out:
# Potability
# non-potable    5000
# potable        5000
# dtype: int64

# %%
df
# Out:
#       Colour (TCU)  Turbidity (NTU)     pH  Conductivity (uS/cm)  \
# 0            25.64             5.74   5.00               1782.74
# 1            16.61             9.22  11.56               2377.82
# 2            14.40             1.38   6.76                656.75
# 3             6.24             3.83   7.33                468.98
# 4            11.10             0.62   6.77                667.87
# ...            ...              ...    ...                   ...
# 9995         12.29             3.65   7.30               1275.35
# 9996         29.90             5.90   0.74               2657.51
# 9997          4.13             2.44   7.90                697.55
# 9998         22.69             5.28   2.22               2273.87
# 9999         21.41             5.02   9.25               1781.15
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                           1646.63                          459.42
# 1                           1356.71                          473.89
# 2                            645.51                          271.57
# 3                            602.06                            1.39
# 4                             15.63                           20.77
# ...                             ...                             ...
# 9995                         552.38                           40.27
# 9996                        1378.30                          370.07
# 9997                         825.41                          245.40
# 9998                        1606.16                          471.20
# 9999                        1552.79                          522.23
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0                 0.34           291.20               0.50         204.48
# 1                 0.29           441.60               0.38         324.94
# 2                 0.10           175.75               0.20         109.39
# 3                 0.20            53.89               0.16          34.96
# 4                 0.04           105.46               0.13          82.78
# ...                ...              ...                ...            ...
# 9995              0.14           164.52               0.28         126.30
# 9996              0.32           258.56               0.45         394.93
# 9997              0.13            33.60               0.17         120.39
# 9998              0.21           448.21               0.33         374.56
# 9999              0.24           442.71               0.47         300.24
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0              778.75         7.24            184.12          284.22
# 1              622.92         6.13            157.13          214.69
# 2              389.46         3.42             54.76          126.21
# 3              237.23         4.76              3.05          127.06
# 4              195.94         4.71             83.24           54.71
# ...               ...          ...               ...             ...
# 9995            92.84         1.68              9.30           51.54
# 9996           561.45         9.67            115.56          169.62
# 9997           259.12         3.44             85.68           19.84
# 9998           454.97         5.45            188.85          169.03
# 9999           699.73         9.36            196.19          229.82
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)   Potability
# 0                70.97           89.72              3.01  non-potable
# 1                66.35           74.61              3.58  non-potable
# 2                32.40           21.17              0.84      potable
# 3                28.69            6.14              1.99      potable
# 4                33.73           29.32              0.06      potable
# ...                ...             ...               ...          ...
# 9995             44.84           11.34              1.27      potable
# 9996             71.34           72.16              2.99  non-potable
# 9997             20.24           15.90              0.82      potable
# 9998             90.34           58.67              3.75  non-potable
# 9999             84.87           64.71              4.40  non-potable
#
# [10000 rows x 18 columns]

# %%
df1
# Out:
#              pH  Total Hardness (mg/l as CaCO3)  Sulphate (mg/l)  \
# 3      8.316766                      214.373394       356.886136
# 4      9.092223                      181.101509       310.135738
# 5      5.584087                      188.313324       326.678363
# 6     10.223862                      248.071735       393.663396
# 7      8.635849                      203.361523       303.309771
# ...         ...                             ...              ...
# 3267   8.989900                      215.047358       312.931022
# 3268   6.702547                      207.321086       304.510230
# 3269  11.491011                       94.812545       258.930600
# 3270   6.069616                      186.659040       345.700257
# 3271   4.668102                      193.681735       359.948574
#
#       Conductivity (uS/cm)   Potability
# 3               363.266516      potable
# 4               398.410813      potable
# 5               280.467916      potable
# 6               283.651634      potable
# 7               474.607645      potable
# ...                    ...          ...
# 3267            390.410231  non-potable
# 3268            329.266002  non-potable
# 3269            439.893618  non-potable
# 3270            415.886955  non-potable
# 3271            526.424171  non-potable
#
# [2011 rows x 5 columns]

# %%
data = pd.concat([df,df1])

# %%
data.isnull().mean()
# Out:
# Colour (TCU)                      0.16743
# Turbidity (NTU)                   0.16743
# pH                                0.00000
# Conductivity (uS/cm)              0.00000
# Total Dissolved Solids (mg/l)     0.16743
# Total Hardness (mg/l as CaCO3)    0.00000
# Aluminium (mg/l)                  0.16743
# Chloride (mg/l)                   0.16743
# Total Iron (mg/l)                 0.16743
# Sodium (mg/l)                     0.16743
# Sulphate (mg/l)                   0.00000
# Zinc (mg/l)                       0.16743
# Magnesium (mg/l)                  0.16743
# Calcium (mg/l)                    0.16743
# Potassium (mg/l)                  0.16743
# Nitrate (mg/l)                    0.16743
# Phosphate (mg/l)                  0.16743
# Potability                        0.00000
# dtype: float64

# %%
from sklearn.impute import SimpleImputer
import numpy as np
mean = SimpleImputer(strategy='mean')

# %%
data_cat = data[['Potability']]

# %%
data = data.drop(columns=['Potability'])

# %%
data
# Out:
#       Colour (TCU)  Turbidity (NTU)         pH  Conductivity (uS/cm)  \
# 0            25.64             5.74   5.000000           1782.740000
# 1            16.61             9.22  11.560000           2377.820000
# 2            14.40             1.38   6.760000            656.750000
# 3             6.24             3.83   7.330000            468.980000
# 4            11.10             0.62   6.770000            667.870000
# ...            ...              ...        ...                   ...
# 3267           NaN              NaN   8.989900            390.410231
# 3268           NaN              NaN   6.702547            329.266002
# 3269           NaN              NaN  11.491011            439.893618
# 3270           NaN              NaN   6.069616            415.886955
# 3271           NaN              NaN   4.668102            526.424171
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                           1646.63                      459.420000
# 1                           1356.71                      473.890000
# 2                            645.51                      271.570000
# 3                            602.06                        1.390000
# 4                             15.63                       20.770000
# ...                             ...                             ...
# 3267                            NaN                      215.047358
# 3268                            NaN                      207.321086
# 3269                            NaN                       94.812545
# 3270                            NaN                      186.659040
# 3271                            NaN                      193.681735
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0                 0.34           291.20               0.50         204.48
# 1                 0.29           441.60               0.38         324.94
# 2                 0.10           175.75               0.20         109.39
# 3                 0.20            53.89               0.16          34.96
# 4                 0.04           105.46               0.13          82.78
# ...                ...              ...                ...            ...
# 3267               NaN              NaN                NaN            NaN
# 3268               NaN              NaN                NaN            NaN
# 3269               NaN              NaN                NaN            NaN
# 3270               NaN              NaN                NaN            NaN
# 3271               NaN              NaN                NaN            NaN
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0          778.750000         7.24            184.12          284.22
# 1          622.920000         6.13            157.13          214.69
# 2          389.460000         3.42             54.76          126.21
# 3          237.230000         4.76              3.05          127.06
# 4          195.940000         4.71             83.24           54.71
# ...               ...          ...               ...             ...
# 3267       312.931022          NaN               NaN             NaN
# 3268       304.510230          NaN               NaN             NaN
# 3269       258.930600          NaN               NaN             NaN
# 3270       345.700257          NaN               NaN             NaN
# 3271       359.948574          NaN               NaN             NaN
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)
# 0                70.97           89.72              3.01
# 1                66.35           74.61              3.58
# 2                32.40           21.17              0.84
# 3                28.69            6.14              1.99
# 4                33.73           29.32              0.06
# ...                ...             ...               ...
# 3267               NaN             NaN               NaN
# 3268               NaN             NaN               NaN
# 3269               NaN             NaN               NaN
# 3270               NaN             NaN               NaN
# 3271               NaN             NaN               NaN
#
# [12011 rows x 17 columns]

# %%
data['Colour (TCU)'] = mean.fit_transform(data[['Colour (TCU)']])

# %%
data['Total Dissolved Solids (mg/l)'] = mean.fit_transform(data[['Total Dissolved Solids (mg/l)']])
data['Turbidity (NTU)'] = mean.fit_transform(data[['Turbidity (NTU)']])
data['Aluminium (mg/l)'] = mean.fit_transform(data[['Aluminium (mg/l)']])
data['Chloride (mg/l)'] = mean.fit_transform(data[['Chloride (mg/l)']])
data['Total Iron (mg/l)'] = mean.fit_transform(data[['Total Iron (mg/l)']])
data['Sodium (mg/l)'] = mean.fit_transform(data[['Sodium (mg/l)']])
data['Zinc (mg/l)'] = mean.fit_transform(data[['Zinc (mg/l)']])
data['Magnesium (mg/l)'] = mean.fit_transform(data[['Magnesium (mg/l)']])
data['Calcium (mg/l)'] = mean.fit_transform(data[['Calcium (mg/l)']])
data['Potassium (mg/l)'] = mean.fit_transform(data[['Potassium (mg/l)']])
data['Nitrate (mg/l)'] = mean.fit_transform(data[['Nitrate (mg/l)']])
data['Phosphate (mg/l)'] = mean.fit_transform(data[['Phosphate (mg/l)']])

# %%
data
# Out:
#       Colour (TCU)  Turbidity (NTU)         pH  Conductivity (uS/cm)  \
# 0        25.640000         5.740000   5.000000           1782.740000
# 1        16.610000         9.220000  11.560000           2377.820000
# 2        14.400000         1.380000   6.760000            656.750000
# 3         6.240000         3.830000   7.330000            468.980000
# 4        11.100000         0.620000   6.770000            667.870000
# ...            ...              ...        ...                   ...
# 3267     15.006526         5.003388   8.989900            390.410231
# 3268     15.006526         5.003388   6.702547            329.266002
# 3269     15.006526         5.003388  11.491011            439.893618
# 3270     15.006526         5.003388   6.069616            415.886955
# 3271     15.006526         5.003388   4.668102            526.424171
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                       1646.630000                      459.420000
# 1                       1356.710000                      473.890000
# 2                        645.510000                      271.570000
# 3                        602.060000                        1.390000
# 4                         15.630000                       20.770000
# ...                             ...                             ...
# 3267                    1001.183584                      215.047358
# 3268                    1001.183584                      207.321086
# 3269                    1001.183584                       94.812545
# 3270                    1001.183584                      186.659040
# 3271                    1001.183584                      193.681735
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0             0.340000       291.200000           0.500000     204.480000
# 1             0.290000       441.600000           0.380000     324.940000
# 2             0.100000       175.750000           0.200000     109.390000
# 3             0.200000        53.890000           0.160000      34.960000
# 4             0.040000       105.460000           0.130000      82.780000
# ...                ...              ...                ...            ...
# 3267          0.200808       249.491721           0.300165     200.793553
# 3268          0.200808       249.491721           0.300165     200.793553
# 3269          0.200808       249.491721           0.300165     200.793553
# 3270          0.200808       249.491721           0.300165     200.793553
# 3271          0.200808       249.491721           0.300165     200.793553
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0          778.750000     7.240000        184.120000      284.220000
# 1          622.920000     6.130000        157.130000      214.690000
# 2          389.460000     3.420000         54.760000      126.210000
# 3          237.230000     4.760000          3.050000      127.060000
# 4          195.940000     4.710000         83.240000       54.710000
# ...               ...          ...               ...             ...
# 3267       312.931022     5.004608        100.026299      149.944522
# 3268       304.510230     5.004608        100.026299      149.944522
# 3269       258.930600     5.004608        100.026299      149.944522
# 3270       345.700257     5.004608        100.026299      149.944522
# 3271       359.948574     5.004608        100.026299      149.944522
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)
# 0            70.970000       89.720000          3.010000
# 1            66.350000       74.610000          3.580000
# 2            32.400000       21.170000          0.840000
# 3            28.690000        6.140000          1.990000
# 4            33.730000       29.320000          0.060000
# ...                ...             ...               ...
# 3267         49.838229       45.162176          2.205561
# 3268         49.838229       45.162176          2.205561
# 3269         49.838229       45.162176          2.205561
# 3270         49.838229       45.162176          2.205561
# 3271         49.838229       45.162176          2.205561
#
# [12011 rows x 17 columns]

# %%
data['Potability'] = data_cat

# %%
data
# Out:
#       Colour (TCU)  Turbidity (NTU)         pH  Conductivity (uS/cm)  \
# 0        25.640000         5.740000   5.000000           1782.740000
# 1        16.610000         9.220000  11.560000           2377.820000
# 2        14.400000         1.380000   6.760000            656.750000
# 3         6.240000         3.830000   7.330000            468.980000
# 4        11.100000         0.620000   6.770000            667.870000
# ...            ...              ...        ...                   ...
# 3267     15.006526         5.003388   8.989900            390.410231
# 3268     15.006526         5.003388   6.702547            329.266002
# 3269     15.006526         5.003388  11.491011            439.893618
# 3270     15.006526         5.003388   6.069616            415.886955
# 3271     15.006526         5.003388   4.668102            526.424171
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                       1646.630000                      459.420000
# 1                       1356.710000                      473.890000
# 2                        645.510000                      271.570000
# 3                        602.060000                        1.390000
# 4                         15.630000                       20.770000
# ...                             ...                             ...
# 3267                    1001.183584                      215.047358
# 3268                    1001.183584                      207.321086
# 3269                    1001.183584                       94.812545
# 3270                    1001.183584                      186.659040
# 3271                    1001.183584                      193.681735
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0             0.340000       291.200000           0.500000     204.480000
# 1             0.290000       441.600000           0.380000     324.940000
# 2             0.100000       175.750000           0.200000     109.390000
# 3             0.200000        53.890000           0.160000      34.960000
# 4             0.040000       105.460000           0.130000      82.780000
# ...                ...              ...                ...            ...
# 3267          0.200808       249.491721           0.300165     200.793553
# 3268          0.200808       249.491721           0.300165     200.793553
# 3269          0.200808       249.491721           0.300165     200.793553
# 3270          0.200808       249.491721           0.300165     200.793553
# 3271          0.200808       249.491721           0.300165     200.793553
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0          778.750000     7.240000        184.120000      284.220000
# 1          622.920000     6.130000        157.130000      214.690000
# 2          389.460000     3.420000         54.760000      126.210000
# 3          237.230000     4.760000          3.050000      127.060000
# 4          195.940000     4.710000         83.240000       54.710000
# ...               ...          ...               ...             ...
# 3267       312.931022     5.004608        100.026299      149.944522
# 3268       304.510230     5.004608        100.026299      149.944522
# 3269       258.930600     5.004608        100.026299      149.944522
# 3270       345.700257     5.004608        100.026299      149.944522
# 3271       359.948574     5.004608        100.026299      149.944522
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)   Potability
# 0            70.970000       89.720000          3.010000  non-potable
# 1            66.350000       74.610000          3.580000  non-potable
# 2            32.400000       21.170000          0.840000      potable
# 3            28.690000        6.140000          1.990000      potable
# 4            33.730000       29.320000          0.060000      potable
# ...                ...             ...               ...          ...
# 3267         49.838229       45.162176          2.205561  non-potable
# 3268         49.838229       45.162176          2.205561  non-potable
# 3269         49.838229       45.162176          2.205561  non-potable
# 3270         49.838229       45.162176          2.205561  non-potable
# 3271         49.838229       45.162176          2.205561  non-potable
#
# [12011 rows x 18 columns]

# %%
data['Potability'].value_counts()
# Out:
# potable        6200
# non-potable    5811
# Name: Potability, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
enc=  OneHotEncoder(sparse=False)
data['Potability'] = enc.fit_transform(data[['Potability']])
# Out:
# C:\Users\bibhz\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:828: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
data
# Out:
#       Colour (TCU)  Turbidity (NTU)         pH  Conductivity (uS/cm)  \
# 0        25.640000         5.740000   5.000000           1782.740000
# 1        16.610000         9.220000  11.560000           2377.820000
# 2        14.400000         1.380000   6.760000            656.750000
# 3         6.240000         3.830000   7.330000            468.980000
# 4        11.100000         0.620000   6.770000            667.870000
# ...            ...              ...        ...                   ...
# 3267     15.006526         5.003388   8.989900            390.410231
# 3268     15.006526         5.003388   6.702547            329.266002
# 3269     15.006526         5.003388  11.491011            439.893618
# 3270     15.006526         5.003388   6.069616            415.886955
# 3271     15.006526         5.003388   4.668102            526.424171
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                       1646.630000                      459.420000
# 1                       1356.710000                      473.890000
# 2                        645.510000                      271.570000
# 3                        602.060000                        1.390000
# 4                         15.630000                       20.770000
# ...                             ...                             ...
# 3267                    1001.183584                      215.047358
# 3268                    1001.183584                      207.321086
# 3269                    1001.183584                       94.812545
# 3270                    1001.183584                      186.659040
# 3271                    1001.183584                      193.681735
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0             0.340000       291.200000           0.500000     204.480000
# 1             0.290000       441.600000           0.380000     324.940000
# 2             0.100000       175.750000           0.200000     109.390000
# 3             0.200000        53.890000           0.160000      34.960000
# 4             0.040000       105.460000           0.130000      82.780000
# ...                ...              ...                ...            ...
# 3267          0.200808       249.491721           0.300165     200.793553
# 3268          0.200808       249.491721           0.300165     200.793553
# 3269          0.200808       249.491721           0.300165     200.793553
# 3270          0.200808       249.491721           0.300165     200.793553
# 3271          0.200808       249.491721           0.300165     200.793553
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0          778.750000     7.240000        184.120000      284.220000
# 1          622.920000     6.130000        157.130000      214.690000
# 2          389.460000     3.420000         54.760000      126.210000
# 3          237.230000     4.760000          3.050000      127.060000
# 4          195.940000     4.710000         83.240000       54.710000
# ...               ...          ...               ...             ...
# 3267       312.931022     5.004608        100.026299      149.944522
# 3268       304.510230     5.004608        100.026299      149.944522
# 3269       258.930600     5.004608        100.026299      149.944522
# 3270       345.700257     5.004608        100.026299      149.944522
# 3271       359.948574     5.004608        100.026299      149.944522
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)  Potability
# 0            70.970000       89.720000          3.010000         1.0
# 1            66.350000       74.610000          3.580000         1.0
# 2            32.400000       21.170000          0.840000         0.0
# 3            28.690000        6.140000          1.990000         0.0
# 4            33.730000       29.320000          0.060000         0.0
# ...                ...             ...               ...         ...
# 3267         49.838229       45.162176          2.205561         1.0
# 3268         49.838229       45.162176          2.205561         1.0
# 3269         49.838229       45.162176          2.205561         1.0
# 3270         49.838229       45.162176          2.205561         1.0
# 3271         49.838229       45.162176          2.205561         1.0
#
# [12011 rows x 18 columns]

# %%
data = data.sample(frac=1)
data = data.reset_index()

data = data.drop(columns=['index'])
data
# Out:
#        Colour (TCU)  Turbidity (NTU)        pH  Conductivity (uS/cm)  \
# 0          8.530000         3.740000   6.57000            196.090000
# 1         26.030000         8.720000   5.03000           2089.490000
# 2          1.730000         0.120000   6.99000            860.070000
# 3         14.680000         1.180000   6.86000            667.400000
# 4          4.450000         2.000000   7.58000            239.480000
# ...             ...              ...       ...                   ...
# 12006     15.006526         5.003388   9.51966            395.698538
# 12007     20.360000         7.960000  11.03000           2284.970000
# 12008      9.780000         1.090000   7.44000            820.680000
# 12009     20.840000         8.520000   2.37000           2018.890000
# 12010     27.890000         5.470000  12.92000           2467.810000
#
#        Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                         527.640000                       47.040000
# 1                        1762.570000                      465.910000
# 2                         866.520000                      160.430000
# 3                         209.250000                      103.110000
# 4                         832.670000                      299.800000
# ...                              ...                             ...
# 12006                    1001.183584                      204.080945
# 12007                    1529.580000                      371.580000
# 12008                     871.340000                      169.690000
# 12009                    1985.300000                      535.570000
# 12010                    1142.120000                      376.950000
#
#        Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0              0.030000       176.630000           0.170000     177.150000
# 1              0.370000       256.550000           0.390000     205.150000
# 2              0.130000       145.890000           0.290000     141.490000
# 3              0.170000        74.240000           0.060000     131.360000
# 4              0.090000         6.320000           0.050000     108.760000
# ...                 ...              ...                ...            ...
# 12006          0.200808       249.491721           0.300165     200.793553
# 12007          0.220000       497.800000           0.600000     324.010000
# 12008          0.090000       227.300000           0.200000      86.990000
# 12009          0.230000       308.150000           0.480000     246.730000
# 12010          0.270000       331.950000           0.320000     394.610000
#
#        Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0           101.050000     4.790000         57.490000       71.900000
# 1           782.550000     5.310000        107.670000      209.580000
# 2           297.320000     1.070000         24.110000      146.360000
# 3           310.320000     3.740000         84.930000       55.020000
# 4           202.760000     4.710000         36.570000       96.020000
# ...                ...          ...               ...             ...
# 12006       310.716294     5.004608        100.026299      149.944522
# 12007       757.140000     9.840000        155.460000      271.500000
# 12008       374.090000     1.620000         18.790000       91.830000
# 12009       474.340000     5.710000        150.980000      268.680000
# 12010       674.600000     6.280000        157.040000      260.370000
#
#        Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)  Potability
# 0              0.030000        1.680000          0.850000         0.0
# 1             76.720000       84.270000          4.160000         1.0
# 2             41.620000       33.390000          1.520000         0.0
# 3             32.860000       22.210000          0.250000         0.0
# 4             11.010000        1.450000          1.690000         0.0
# ...                 ...             ...               ...         ...
# 12006         49.838229       45.162176          2.205561         0.0
# 12007         54.380000       86.870000          3.220000         1.0
# 12008         32.030000        6.220000          2.040000         0.0
# 12009         64.340000       73.180000          2.590000         1.0
# 12010         78.910000       78.440000          3.760000         1.0
#
# [12011 rows x 18 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
corr = data.corr()
plt.figure(figsize=(14,12))
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
X = data.drop(columns='Potability')
y = data['Potability']

# %%
from sklearn.model_selection import StratifiedKFold
folds = StratifiedKFold(n_splits=5)
num_folds = 3

# %%
for train_index, test_index in folds.split(X, y):
    
    
    # Split the data into training and test sets for the current fold
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# %%
X_train.shape
# Out:
# (9609, 17)

# %%
X_test.shape
# Out:
# (2402, 17)

# %%
y_train.shape
# Out:
# (9609,)

# %%
y_test.shape
# Out:
# (2402,)

# %%
from sklearn.linear_model import LogisticRegression,RidgeClassifier,SGDClassifier,PassiveAggressiveClassifier
from sklearn.linear_model import Perceptron
from sklearn.svm import SVC,LinearSVC,NuSVC
from sklearn.neighbors import KNeighborsClassifier,NearestCentroid
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB,BernoulliNB
from sklearn.ensemble import VotingClassifier

from sklearn.metrics import precision_score,accuracy_score
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV,RepeatedStratifiedKFold

# %%
model = SVC()

# %%
model.fit(X_train,y_train)
# Out:
# SVC()

# %%
model.score(X_test,y_test)
# Out:
# 0.9371357202331391

# %%
[y_train]
# Out:
# [0       0.0
#  1       1.0
#  2       0.0
#  3       0.0
#  4       0.0
#         ...
#  9605    1.0
#  9606    1.0
#  9607    1.0
#  9609    1.0
#  9610    1.0
#  Name: Potability, Length: 9609, dtype: float64]

# %%
y_pred.shape
# Out:
# (2402,)

# %%
from sklearn.metrics import accuracy_score, precision_score

# %%
y_pred = model.predict(X_test)

# %%
y_pred2 = model.predict(X_train)

# %%
test_accuracy = accuracy_score(y_test, y_pred)

# %%
print(test_accuracy)
# Out:
# 0.9371357202331391

# %%
precision = precision_score(y_test, y_pred)

# %%
print(precision)
# Out:
# 1.0

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(model, X, y, cv=5)
print(scores)
# Out:
# [0.93591344 0.93130724 0.92880933 0.92922565 0.93713572]

# %%
from sklearn.model_selection import learning_curve
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
import seaborn as sns

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred)

# %%
from sklearn.metrics import ConfusionMatrixDisplay
a = ConfusionMatrixDisplay(cm)
a.plot()
plt.show()

# %%
def plot_learning_curve(estimator, X, y):
    train_sizes, train_scores, test_scores = learning_curve(estimator, X, y, cv=5,
                                                            train_sizes=np.linspace(0.1, 1.0, 10))
    train_mean = np.mean(train_scores, axis=1)
    train_std = np.std(train_scores, axis=1)
    test_mean = np.mean(test_scores, axis=1)
    test_std = np.std(test_scores, axis=1)

    # Plot learning curve
    plt.figure(figsize=(10, 6))
    plt.plot(train_sizes, train_mean, 'o-', color='r', label='Training Score')
    plt.plot(train_sizes, test_mean, 'o-', color='g', label='Cross-Validation Score')
    plt.fill_between(train_sizes, train_mean - train_std, train_mean + train_std, alpha=0.1, color='r')
    plt.fill_between(train_sizes, test_mean - test_std, test_mean + test_std, alpha=0.1, color='g')
    plt.xlabel('Training Examples')
    plt.ylabel('Score')
    plt.title('Learning Curve')
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()

# Plot the learning curve
plot_learning_curve(model, X, y)

# %%
from sklearn.metrics import log_loss

# %%
training_loss = log_loss(y_train, y_pred2)
validation_loss = log_loss(y_test, y_pred)
print("Training Loss:", training_loss)
print("Validation Loss:", validation_loss)
# Out:
# Training Loss: 2.4756802202952772
# Validation Loss: 2.2658583104732264

# %%
def plot_learning_curve(estimator, X, y):
    train_sizes, train_scores, test_scores = learning_curve(estimator, X, y, cv=5,
                                                            scoring='accuracy')
    train_scores = 1-np.mean(train_scores, axis=1)
    test_scores = 1-np.mean(test_scores, axis=1)
    lc = pd.DataFrame({"Training_size":train_sizes,"Training_loss":train_scores,"Validation_loss":test_scores}).melt(id_vars="Training_size")
    return {"train_score":train_scores,"learning_curve":lc}

# %%
lc = plot_learning_curve(model,X,y)
sns.lineplot(data=lc["learning_curve"],x="Training_size",y="value",hue="variable")
plt.title("Learning Curve of Model")
plt.ylabel("Misclassification Rate/Loss");
