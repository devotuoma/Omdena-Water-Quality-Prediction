# %%
import pandas as pd

# %%
df = pd.read_csv('raw.githubusercontent.com_OmdenaAI_rwanda-chapter-water-quality-prediction_main_src_data_Synthetic_Data_Water_Quality.csv_token=GHSAT0AAAAAACDPMDQNJQY6HC4V722ZW3VCZEIDFVQ.csv')

# %%
df
# Out:
#       Colour (TCU)  Turbidity (NTU)    pH  Conductivity (uS/cm)  \
# 0             8.34             3.39  8.06                819.00
# 1            14.45             3.36  8.28               1371.10
# 2             3.87             4.23  6.86                202.75
# 3            14.57             1.75  7.00                696.16
# 4             9.01             2.20  6.73                129.24
# ...            ...              ...   ...                   ...
# 9995         27.64             9.46  0.09               2422.27
# 9996         25.58             8.61  4.39               1516.78
# 9997         19.40             8.16  3.05               2456.68
# 9998         18.73             5.03  9.35               1900.45
# 9999         27.30             8.66  9.22               2750.24
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                            787.15                          279.89
# 1                            779.66                          112.04
# 2                            485.10                          113.17
# 3                            409.71                          140.39
# 4                            343.55                            6.52
# ...                             ...                             ...
# 9995                        1147.04                          521.18
# 9996                        1604.78                          429.84
# 9997                        1439.54                          483.23
# 9998                        1092.84                          458.86
# 9999                        1058.46                          492.12
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0                 0.09           129.30               0.22          13.13
# 1                 0.20           163.73               0.13         127.48
# 2                 0.15            66.68               0.29         142.97
# 3                 0.06           102.42               0.15         194.07
# 4                 0.07           140.47               0.28           3.77
# ...                ...              ...                ...            ...
# 9995              0.24           362.50               0.41         283.40
# 9996              0.33           394.23               0.55         303.78
# 9997              0.40           348.95               0.48         229.37
# 9998              0.28           289.98               0.52         310.67
# 9999              0.35           283.16               0.59         247.13
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0               81.01         2.24             12.69          107.95
# 1              307.99         4.05             52.01          107.12
# 2               16.70         0.86             88.47          127.47
# 3              393.09         2.60             61.36           99.16
# 4              170.65         0.04             47.22          107.17
# ...               ...          ...               ...             ...
# 9995           438.94         9.88            112.00          258.93
# 9996           556.85         8.87            122.23          284.79
# 9997           690.85         6.67            136.61          198.87
# 9998           564.05         7.22            108.37          260.68
# 9999           423.96         8.42            149.07          266.26
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)   Potability
# 0                17.50           22.23              0.41      potable
# 1                45.28           16.06              0.68      potable
# 2                 4.90           19.81              0.91      potable
# 3                36.73           42.82              0.02      potable
# 4                44.79           14.35              2.08      potable
# ...                ...             ...               ...          ...
# 9995             70.92           81.10              3.09  non-potable
# 9996             76.31           79.69              2.48  non-potable
# 9997             68.99           53.38              3.37  non-potable
# 9998             82.73           83.58              2.78  non-potable
# 9999             87.11           51.96              4.11  non-potable
#
# [10000 rows x 18 columns]

# %%
df = df.sample(frac=1)

# %%
df
# Out:
#       Colour (TCU)  Turbidity (NTU)     pH  Conductivity (uS/cm)  \
# 8323         28.08             6.75  12.07               1994.98
# 4709          4.33             0.18   7.75                655.63
# 7796         21.18             5.54   0.16               1689.11
# 5599         24.82             6.93   8.85               2675.59
# 5908         17.29             7.74   4.81               2580.21
# ...            ...              ...    ...                   ...
# 1078          8.02             2.60   8.34                310.45
# 1719          4.96             1.87   8.22                529.42
# 5195         20.76             6.90   4.18               2167.02
# 3055          8.84             3.71   6.89                818.57
# 2195          3.71             0.48   7.53                754.75
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 8323                        1229.73                          462.42
# 4709                         387.76                          254.61
# 7796                        1597.06                          510.80
# 5599                        1074.96                          573.61
# 5908                        1412.61                          507.95
# ...                             ...                             ...
# 1078                         639.12                           53.48
# 1719                         896.62                          197.51
# 5195                        1277.16                          424.04
# 3055                         536.94                           22.17
# 2195                         112.76                            8.47
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 8323              0.38           380.92               0.56         201.89
# 4709              0.13            38.33               0.18         131.75
# 7796              0.22           495.92               0.37         234.18
# 5599              0.28           332.48               0.31         275.85
# 5908              0.39           271.13               0.41         315.39
# ...                ...              ...                ...            ...
# 1078              0.16            41.98               0.10          14.35
# 1719              0.09           247.10               0.22          54.45
# 5195              0.29           337.98               0.50         375.31
# 3055              0.13            57.89               0.29           9.04
# 2195              0.17           112.46               0.16         138.05
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 8323           664.21         8.73            162.13          277.31
# 4709            18.48         3.22             29.31           25.73
# 7796           495.76         7.77            120.50          168.72
# 5599           506.47         9.89            126.69          180.60
# 5908           578.70         6.88            128.15          275.65
# ...               ...          ...               ...             ...
# 1078           306.06         0.45             73.81           33.22
# 1719           110.44         3.72             37.46           93.43
# 5195           565.01         5.41            133.39          267.93
# 3055           128.93         2.98             87.55          147.44
# 2195           145.98         1.89             90.47          141.95
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)   Potability
# 8323             95.19           69.89              4.04  non-potable
# 4709             43.92           22.55              0.98      potable
# 7796             87.90           80.93              3.17  non-potable
# 5599             71.17           71.39              3.05  non-potable
# 5908             58.25           66.87              2.48  non-potable
# ...                ...             ...               ...          ...
# 1078             13.50           17.31              1.72      potable
# 1719             27.62           35.13              1.58      potable
# 5195             89.02           52.95              3.52  non-potable
# 3055              4.07           30.27              0.15      potable
# 2195             13.97           24.35              0.97      potable
#
# [10000 rows x 18 columns]

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       index  Colour (TCU)  Turbidity (NTU)     pH  Conductivity (uS/cm)  \
# 0      8323         28.08             6.75  12.07               1994.98
# 1      4709          4.33             0.18   7.75                655.63
# 2      7796         21.18             5.54   0.16               1689.11
# 3      5599         24.82             6.93   8.85               2675.59
# 4      5908         17.29             7.74   4.81               2580.21
# ...     ...           ...              ...    ...                   ...
# 9995   1078          8.02             2.60   8.34                310.45
# 9996   1719          4.96             1.87   8.22                529.42
# 9997   5195         20.76             6.90   4.18               2167.02
# 9998   3055          8.84             3.71   6.89                818.57
# 9999   2195          3.71             0.48   7.53                754.75
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                           1229.73                          462.42
# 1                            387.76                          254.61
# 2                           1597.06                          510.80
# 3                           1074.96                          573.61
# 4                           1412.61                          507.95
# ...                             ...                             ...
# 9995                         639.12                           53.48
# 9996                         896.62                          197.51
# 9997                        1277.16                          424.04
# 9998                         536.94                           22.17
# 9999                         112.76                            8.47
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0                 0.38           380.92               0.56         201.89
# 1                 0.13            38.33               0.18         131.75
# 2                 0.22           495.92               0.37         234.18
# 3                 0.28           332.48               0.31         275.85
# 4                 0.39           271.13               0.41         315.39
# ...                ...              ...                ...            ...
# 9995              0.16            41.98               0.10          14.35
# 9996              0.09           247.10               0.22          54.45
# 9997              0.29           337.98               0.50         375.31
# 9998              0.13            57.89               0.29           9.04
# 9999              0.17           112.46               0.16         138.05
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0              664.21         8.73            162.13          277.31
# 1               18.48         3.22             29.31           25.73
# 2              495.76         7.77            120.50          168.72
# 3              506.47         9.89            126.69          180.60
# 4              578.70         6.88            128.15          275.65
# ...               ...          ...               ...             ...
# 9995           306.06         0.45             73.81           33.22
# 9996           110.44         3.72             37.46           93.43
# 9997           565.01         5.41            133.39          267.93
# 9998           128.93         2.98             87.55          147.44
# 9999           145.98         1.89             90.47          141.95
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)   Potability
# 0                95.19           69.89              4.04  non-potable
# 1                43.92           22.55              0.98      potable
# 2                87.90           80.93              3.17  non-potable
# 3                71.17           71.39              3.05  non-potable
# 4                58.25           66.87              2.48  non-potable
# ...                ...             ...               ...          ...
# 9995             13.50           17.31              1.72      potable
# 9996             27.62           35.13              1.58      potable
# 9997             89.02           52.95              3.52  non-potable
# 9998              4.07           30.27              0.15      potable
# 9999             13.97           24.35              0.97      potable
#
# [10000 rows x 19 columns]

# %%
df = df.drop(columns=['index'])

# %%
df
# Out:
#       Colour (TCU)  Turbidity (NTU)     pH  Conductivity (uS/cm)  \
# 0            28.08             6.75  12.07               1994.98
# 1             4.33             0.18   7.75                655.63
# 2            21.18             5.54   0.16               1689.11
# 3            24.82             6.93   8.85               2675.59
# 4            17.29             7.74   4.81               2580.21
# ...            ...              ...    ...                   ...
# 9995          8.02             2.60   8.34                310.45
# 9996          4.96             1.87   8.22                529.42
# 9997         20.76             6.90   4.18               2167.02
# 9998          8.84             3.71   6.89                818.57
# 9999          3.71             0.48   7.53                754.75
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                           1229.73                          462.42
# 1                            387.76                          254.61
# 2                           1597.06                          510.80
# 3                           1074.96                          573.61
# 4                           1412.61                          507.95
# ...                             ...                             ...
# 9995                         639.12                           53.48
# 9996                         896.62                          197.51
# 9997                        1277.16                          424.04
# 9998                         536.94                           22.17
# 9999                         112.76                            8.47
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0                 0.38           380.92               0.56         201.89
# 1                 0.13            38.33               0.18         131.75
# 2                 0.22           495.92               0.37         234.18
# 3                 0.28           332.48               0.31         275.85
# 4                 0.39           271.13               0.41         315.39
# ...                ...              ...                ...            ...
# 9995              0.16            41.98               0.10          14.35
# 9996              0.09           247.10               0.22          54.45
# 9997              0.29           337.98               0.50         375.31
# 9998              0.13            57.89               0.29           9.04
# 9999              0.17           112.46               0.16         138.05
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0              664.21         8.73            162.13          277.31
# 1               18.48         3.22             29.31           25.73
# 2              495.76         7.77            120.50          168.72
# 3              506.47         9.89            126.69          180.60
# 4              578.70         6.88            128.15          275.65
# ...               ...          ...               ...             ...
# 9995           306.06         0.45             73.81           33.22
# 9996           110.44         3.72             37.46           93.43
# 9997           565.01         5.41            133.39          267.93
# 9998           128.93         2.98             87.55          147.44
# 9999           145.98         1.89             90.47          141.95
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)   Potability
# 0                95.19           69.89              4.04  non-potable
# 1                43.92           22.55              0.98      potable
# 2                87.90           80.93              3.17  non-potable
# 3                71.17           71.39              3.05  non-potable
# 4                58.25           66.87              2.48  non-potable
# ...                ...             ...               ...          ...
# 9995             13.50           17.31              1.72      potable
# 9996             27.62           35.13              1.58      potable
# 9997             89.02           52.95              3.52  non-potable
# 9998              4.07           30.27              0.15      potable
# 9999             13.97           24.35              0.97      potable
#
# [10000 rows x 18 columns]

# %%
df1 = pd.read_csv('water_potability.csv')

# %%
df1
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0          NaN  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246         NaN
# 2     8.099124  224.236259  19909.541732     9.275884         NaN
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362         NaN
# 3273  9.419510  175.762646  33155.578218     7.350233         NaN
# 3274  5.126763  230.603758  11983.869376     6.303357         NaN
# 3275  7.874671  195.102299  17404.177061     7.509306         NaN
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       564.308654       10.379783        86.990970   2.963135           0
# 1       592.885359       15.180013        56.329076   4.500656           0
# 2       418.606213       16.868637        66.420093   3.055934           0
# 3       363.266516       18.436524       100.341674   4.628771           0
# 4       398.410813       11.558279        31.997993   4.075075           0
# ...            ...             ...              ...        ...         ...
# 3271    526.424171       13.894419        66.687695   4.435821           1
# 3272    392.449580       19.903225              NaN   2.798243           1
# 3273    432.044783       11.039070        69.845400   3.298875           1
# 3274    402.883113       11.168946        77.488213   4.708658           1
# 3275    327.459760       16.140368        78.698446   2.309149           1
#
# [3276 rows x 10 columns]

# %%
df1 = df1.dropna()

# %%
df1
# Out:
#              ph    Hardness        Solids  Chloramines     Sulfate  \
# 3      8.316766  214.373394  22018.417441     8.059332  356.886136
# 4      9.092223  181.101509  17978.986339     6.546600  310.135738
# 5      5.584087  188.313324  28748.687739     7.544869  326.678363
# 6     10.223862  248.071735  28749.716544     7.513408  393.663396
# 7      8.635849  203.361523  13672.091764     4.563009  303.309771
# ...         ...         ...           ...          ...         ...
# 3267   8.989900  215.047358  15921.412018     6.297312  312.931022
# 3268   6.702547  207.321086  17246.920347     7.708117  304.510230
# 3269  11.491011   94.812545  37188.826022     9.263166  258.930600
# 3270   6.069616  186.659040  26138.780191     7.747547  345.700257
# 3271   4.668102  193.681735  47580.991603     7.166639  359.948574
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 3       363.266516       18.436524       100.341674   4.628771           0
# 4       398.410813       11.558279        31.997993   4.075075           0
# 5       280.467916        8.399735        54.917862   2.559708           0
# 6       283.651634       13.789695        84.603556   2.672989           0
# 7       474.607645       12.363817        62.798309   4.401425           0
# ...            ...             ...              ...        ...         ...
# 3267    390.410231        9.899115        55.069304   4.613843           1
# 3268    329.266002       16.217303        28.878601   3.442983           1
# 3269    439.893618       16.172755        41.558501   4.369264           1
# 3270    415.886955       12.067620        60.419921   3.669712           1
# 3271    526.424171       13.894419        66.687695   4.435821           1
#
# [2011 rows x 10 columns]

# %%
mapping = {1: 'non-potable', 0: 'potable'}

# Applying the mapping using replace
df1['Potability'] = df1['Potability'].replace(mapping)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\pandas\core\frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
df1.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Colour (TCU)', 'Turbidity (NTU)', 'pH', 'Conductivity (uS/cm)',
#        'Total Dissolved Solids (mg/l)', 'Total Hardness (mg/l as CaCO3)',
#        'Aluminium (mg/l)', 'Chloride (mg/l)', 'Total Iron (mg/l)',
#        'Sodium (mg/l)', 'Sulphate (mg/l)', 'Zinc (mg/l)', 'Magnesium (mg/l)',
#        'Calcium (mg/l)', 'Potassium (mg/l)', 'Nitrate (mg/l)',
#        'Phosphate (mg/l)', 'Potability'],
#       dtype='object')

# %%
df1 = df1.rename(columns={'ph':'pH','Hardness':'Total Hardness (mg/l as CaCO3)','Sulfate':'Sulphate (mg/l)','Conductivity':'Conductivity (uS/cm)'})

# %%
df1
# Out:
#              pH  Total Hardness (mg/l as CaCO3)        Solids  Chloramines  \
# 3      8.316766                      214.373394  22018.417441     8.059332
# 4      9.092223                      181.101509  17978.986339     6.546600
# 5      5.584087                      188.313324  28748.687739     7.544869
# 6     10.223862                      248.071735  28749.716544     7.513408
# 7      8.635849                      203.361523  13672.091764     4.563009
# ...         ...                             ...           ...          ...
# 3267   8.989900                      215.047358  15921.412018     6.297312
# 3268   6.702547                      207.321086  17246.920347     7.708117
# 3269  11.491011                       94.812545  37188.826022     9.263166
# 3270   6.069616                      186.659040  26138.780191     7.747547
# 3271   4.668102                      193.681735  47580.991603     7.166639
#
#       Sulphate (mg/l)  Conductivity (uS/cm)  Organic_carbon  Trihalomethanes  \
# 3          356.886136            363.266516       18.436524       100.341674
# 4          310.135738            398.410813       11.558279        31.997993
# 5          326.678363            280.467916        8.399735        54.917862
# 6          393.663396            283.651634       13.789695        84.603556
# 7          303.309771            474.607645       12.363817        62.798309
# ...               ...                   ...             ...              ...
# 3267       312.931022            390.410231        9.899115        55.069304
# 3268       304.510230            329.266002       16.217303        28.878601
# 3269       258.930600            439.893618       16.172755        41.558501
# 3270       345.700257            415.886955       12.067620        60.419921
# 3271       359.948574            526.424171       13.894419        66.687695
#
#       Turbidity   Potability
# 3      4.628771      potable
# 4      4.075075      potable
# 5      2.559708      potable
# 6      2.672989      potable
# 7      4.401425      potable
# ...         ...          ...
# 3267   4.613843  non-potable
# 3268   3.442983  non-potable
# 3269   4.369264  non-potable
# 3270   3.669712  non-potable
# 3271   4.435821  non-potable
#
# [2011 rows x 10 columns]

# %%
df1 = df1.drop(columns=['Solids','Chloramines','Organic_carbon','Trihalomethanes','Turbidity'])

# %%
df1
# Out:
#              pH  Total Hardness (mg/l as CaCO3)  Sulphate (mg/l)  \
# 3      8.316766                      214.373394       356.886136
# 4      9.092223                      181.101509       310.135738
# 5      5.584087                      188.313324       326.678363
# 6     10.223862                      248.071735       393.663396
# 7      8.635849                      203.361523       303.309771
# ...         ...                             ...              ...
# 3267   8.989900                      215.047358       312.931022
# 3268   6.702547                      207.321086       304.510230
# 3269  11.491011                       94.812545       258.930600
# 3270   6.069616                      186.659040       345.700257
# 3271   4.668102                      193.681735       359.948574
#
#       Conductivity (uS/cm)   Potability
# 3               363.266516      potable
# 4               398.410813      potable
# 5               280.467916      potable
# 6               283.651634      potable
# 7               474.607645      potable
# ...                    ...          ...
# 3267            390.410231  non-potable
# 3268            329.266002  non-potable
# 3269            439.893618  non-potable
# 3270            415.886955  non-potable
# 3271            526.424171  non-potable
#
# [2011 rows x 5 columns]

# %%
df
# Out:
#       Colour (TCU)  Turbidity (NTU)     pH  Conductivity (uS/cm)  \
# 0            28.08             6.75  12.07               1994.98
# 1             4.33             0.18   7.75                655.63
# 2            21.18             5.54   0.16               1689.11
# 3            24.82             6.93   8.85               2675.59
# 4            17.29             7.74   4.81               2580.21
# ...            ...              ...    ...                   ...
# 9995          8.02             2.60   8.34                310.45
# 9996          4.96             1.87   8.22                529.42
# 9997         20.76             6.90   4.18               2167.02
# 9998          8.84             3.71   6.89                818.57
# 9999          3.71             0.48   7.53                754.75
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                           1229.73                          462.42
# 1                            387.76                          254.61
# 2                           1597.06                          510.80
# 3                           1074.96                          573.61
# 4                           1412.61                          507.95
# ...                             ...                             ...
# 9995                         639.12                           53.48
# 9996                         896.62                          197.51
# 9997                        1277.16                          424.04
# 9998                         536.94                           22.17
# 9999                         112.76                            8.47
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0                 0.38           380.92               0.56         201.89
# 1                 0.13            38.33               0.18         131.75
# 2                 0.22           495.92               0.37         234.18
# 3                 0.28           332.48               0.31         275.85
# 4                 0.39           271.13               0.41         315.39
# ...                ...              ...                ...            ...
# 9995              0.16            41.98               0.10          14.35
# 9996              0.09           247.10               0.22          54.45
# 9997              0.29           337.98               0.50         375.31
# 9998              0.13            57.89               0.29           9.04
# 9999              0.17           112.46               0.16         138.05
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0              664.21         8.73            162.13          277.31
# 1               18.48         3.22             29.31           25.73
# 2              495.76         7.77            120.50          168.72
# 3              506.47         9.89            126.69          180.60
# 4              578.70         6.88            128.15          275.65
# ...               ...          ...               ...             ...
# 9995           306.06         0.45             73.81           33.22
# 9996           110.44         3.72             37.46           93.43
# 9997           565.01         5.41            133.39          267.93
# 9998           128.93         2.98             87.55          147.44
# 9999           145.98         1.89             90.47          141.95
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)   Potability
# 0                95.19           69.89              4.04  non-potable
# 1                43.92           22.55              0.98      potable
# 2                87.90           80.93              3.17  non-potable
# 3                71.17           71.39              3.05  non-potable
# 4                58.25           66.87              2.48  non-potable
# ...                ...             ...               ...          ...
# 9995             13.50           17.31              1.72      potable
# 9996             27.62           35.13              1.58      potable
# 9997             89.02           52.95              3.52  non-potable
# 9998              4.07           30.27              0.15      potable
# 9999             13.97           24.35              0.97      potable
#
# [10000 rows x 18 columns]

# %%
df[['Potability']].value_counts()
# Out:
# Potability
# non-potable    5000
# potable        5000
# dtype: int64

# %%
df
# Out:
#       Colour (TCU)  Turbidity (NTU)     pH  Conductivity (uS/cm)  \
# 0            28.08             6.75  12.07               1994.98
# 1             4.33             0.18   7.75                655.63
# 2            21.18             5.54   0.16               1689.11
# 3            24.82             6.93   8.85               2675.59
# 4            17.29             7.74   4.81               2580.21
# ...            ...              ...    ...                   ...
# 9995          8.02             2.60   8.34                310.45
# 9996          4.96             1.87   8.22                529.42
# 9997         20.76             6.90   4.18               2167.02
# 9998          8.84             3.71   6.89                818.57
# 9999          3.71             0.48   7.53                754.75
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                           1229.73                          462.42
# 1                            387.76                          254.61
# 2                           1597.06                          510.80
# 3                           1074.96                          573.61
# 4                           1412.61                          507.95
# ...                             ...                             ...
# 9995                         639.12                           53.48
# 9996                         896.62                          197.51
# 9997                        1277.16                          424.04
# 9998                         536.94                           22.17
# 9999                         112.76                            8.47
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0                 0.38           380.92               0.56         201.89
# 1                 0.13            38.33               0.18         131.75
# 2                 0.22           495.92               0.37         234.18
# 3                 0.28           332.48               0.31         275.85
# 4                 0.39           271.13               0.41         315.39
# ...                ...              ...                ...            ...
# 9995              0.16            41.98               0.10          14.35
# 9996              0.09           247.10               0.22          54.45
# 9997              0.29           337.98               0.50         375.31
# 9998              0.13            57.89               0.29           9.04
# 9999              0.17           112.46               0.16         138.05
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0              664.21         8.73            162.13          277.31
# 1               18.48         3.22             29.31           25.73
# 2              495.76         7.77            120.50          168.72
# 3              506.47         9.89            126.69          180.60
# 4              578.70         6.88            128.15          275.65
# ...               ...          ...               ...             ...
# 9995           306.06         0.45             73.81           33.22
# 9996           110.44         3.72             37.46           93.43
# 9997           565.01         5.41            133.39          267.93
# 9998           128.93         2.98             87.55          147.44
# 9999           145.98         1.89             90.47          141.95
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)   Potability
# 0                95.19           69.89              4.04  non-potable
# 1                43.92           22.55              0.98      potable
# 2                87.90           80.93              3.17  non-potable
# 3                71.17           71.39              3.05  non-potable
# 4                58.25           66.87              2.48  non-potable
# ...                ...             ...               ...          ...
# 9995             13.50           17.31              1.72      potable
# 9996             27.62           35.13              1.58      potable
# 9997             89.02           52.95              3.52  non-potable
# 9998              4.07           30.27              0.15      potable
# 9999             13.97           24.35              0.97      potable
#
# [10000 rows x 18 columns]

# %%
df1
# Out:
#              pH  Total Hardness (mg/l as CaCO3)  Sulphate (mg/l)  \
# 3      8.316766                      214.373394       356.886136
# 4      9.092223                      181.101509       310.135738
# 5      5.584087                      188.313324       326.678363
# 6     10.223862                      248.071735       393.663396
# 7      8.635849                      203.361523       303.309771
# ...         ...                             ...              ...
# 3267   8.989900                      215.047358       312.931022
# 3268   6.702547                      207.321086       304.510230
# 3269  11.491011                       94.812545       258.930600
# 3270   6.069616                      186.659040       345.700257
# 3271   4.668102                      193.681735       359.948574
#
#       Conductivity (uS/cm)   Potability
# 3               363.266516      potable
# 4               398.410813      potable
# 5               280.467916      potable
# 6               283.651634      potable
# 7               474.607645      potable
# ...                    ...          ...
# 3267            390.410231  non-potable
# 3268            329.266002  non-potable
# 3269            439.893618  non-potable
# 3270            415.886955  non-potable
# 3271            526.424171  non-potable
#
# [2011 rows x 5 columns]

# %%
data = pd.concat([df,df1])

# %%
data.isnull().mean()
# Out:
# Colour (TCU)                      0.16743
# Turbidity (NTU)                   0.16743
# pH                                0.00000
# Conductivity (uS/cm)              0.00000
# Total Dissolved Solids (mg/l)     0.16743
# Total Hardness (mg/l as CaCO3)    0.00000
# Aluminium (mg/l)                  0.16743
# Chloride (mg/l)                   0.16743
# Total Iron (mg/l)                 0.16743
# Sodium (mg/l)                     0.16743
# Sulphate (mg/l)                   0.00000
# Zinc (mg/l)                       0.16743
# Magnesium (mg/l)                  0.16743
# Calcium (mg/l)                    0.16743
# Potassium (mg/l)                  0.16743
# Nitrate (mg/l)                    0.16743
# Phosphate (mg/l)                  0.16743
# Potability                        0.00000
# dtype: float64

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
sns.displot(data['Magnesium (mg/l)'])

# %%
from sklearn.impute import SimpleImputer
import numpy as np
mean = SimpleImputer(strategy='mean')

# %%
data_cat = data[['Potability']]

# %%
data = data.drop(columns=['Potability'])

# %%
data
# Out:
#       Colour (TCU)  Turbidity (NTU)         pH  Conductivity (uS/cm)  \
# 0            28.08             6.75  12.070000           1994.980000
# 1             4.33             0.18   7.750000            655.630000
# 2            21.18             5.54   0.160000           1689.110000
# 3            24.82             6.93   8.850000           2675.590000
# 4            17.29             7.74   4.810000           2580.210000
# ...            ...              ...        ...                   ...
# 3267           NaN              NaN   8.989900            390.410231
# 3268           NaN              NaN   6.702547            329.266002
# 3269           NaN              NaN  11.491011            439.893618
# 3270           NaN              NaN   6.069616            415.886955
# 3271           NaN              NaN   4.668102            526.424171
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                           1229.73                      462.420000
# 1                            387.76                      254.610000
# 2                           1597.06                      510.800000
# 3                           1074.96                      573.610000
# 4                           1412.61                      507.950000
# ...                             ...                             ...
# 3267                            NaN                      215.047358
# 3268                            NaN                      207.321086
# 3269                            NaN                       94.812545
# 3270                            NaN                      186.659040
# 3271                            NaN                      193.681735
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0                 0.38           380.92               0.56         201.89
# 1                 0.13            38.33               0.18         131.75
# 2                 0.22           495.92               0.37         234.18
# 3                 0.28           332.48               0.31         275.85
# 4                 0.39           271.13               0.41         315.39
# ...                ...              ...                ...            ...
# 3267               NaN              NaN                NaN            NaN
# 3268               NaN              NaN                NaN            NaN
# 3269               NaN              NaN                NaN            NaN
# 3270               NaN              NaN                NaN            NaN
# 3271               NaN              NaN                NaN            NaN
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0          664.210000         8.73            162.13          277.31
# 1           18.480000         3.22             29.31           25.73
# 2          495.760000         7.77            120.50          168.72
# 3          506.470000         9.89            126.69          180.60
# 4          578.700000         6.88            128.15          275.65
# ...               ...          ...               ...             ...
# 3267       312.931022          NaN               NaN             NaN
# 3268       304.510230          NaN               NaN             NaN
# 3269       258.930600          NaN               NaN             NaN
# 3270       345.700257          NaN               NaN             NaN
# 3271       359.948574          NaN               NaN             NaN
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)
# 0                95.19           69.89              4.04
# 1                43.92           22.55              0.98
# 2                87.90           80.93              3.17
# 3                71.17           71.39              3.05
# 4                58.25           66.87              2.48
# ...                ...             ...               ...
# 3267               NaN             NaN               NaN
# 3268               NaN             NaN               NaN
# 3269               NaN             NaN               NaN
# 3270               NaN             NaN               NaN
# 3271               NaN             NaN               NaN
#
# [12011 rows x 17 columns]

# %%
data['Colour (TCU)'] = mean.fit_transform(data[['Colour (TCU)']])

# %%
data['Total Dissolved Solids (mg/l)'] = mean.fit_transform(data[['Total Dissolved Solids (mg/l)']])
data['Turbidity (NTU)'] = mean.fit_transform(data[['Turbidity (NTU)']])
data['Aluminium (mg/l)'] = mean.fit_transform(data[['Aluminium (mg/l)']])
data['Chloride (mg/l)'] = mean.fit_transform(data[['Chloride (mg/l)']])
data['Total Iron (mg/l)'] = mean.fit_transform(data[['Total Iron (mg/l)']])
data['Sodium (mg/l)'] = mean.fit_transform(data[['Sodium (mg/l)']])
data['Zinc (mg/l)'] = mean.fit_transform(data[['Zinc (mg/l)']])
data['Magnesium (mg/l)'] = mean.fit_transform(data[['Magnesium (mg/l)']])
data['Calcium (mg/l)'] = mean.fit_transform(data[['Calcium (mg/l)']])
data['Potassium (mg/l)'] = mean.fit_transform(data[['Potassium (mg/l)']])
data['Nitrate (mg/l)'] = mean.fit_transform(data[['Nitrate (mg/l)']])
data['Phosphate (mg/l)'] = mean.fit_transform(data[['Phosphate (mg/l)']])

# %%
data
# Out:
#       Colour (TCU)  Turbidity (NTU)         pH  Conductivity (uS/cm)  \
# 0        28.080000         6.750000  12.070000           1994.980000
# 1         4.330000         0.180000   7.750000            655.630000
# 2        21.180000         5.540000   0.160000           1689.110000
# 3        24.820000         6.930000   8.850000           2675.590000
# 4        17.290000         7.740000   4.810000           2580.210000
# ...            ...              ...        ...                   ...
# 3267     15.006526         5.003388   8.989900            390.410231
# 3268     15.006526         5.003388   6.702547            329.266002
# 3269     15.006526         5.003388  11.491011            439.893618
# 3270     15.006526         5.003388   6.069616            415.886955
# 3271     15.006526         5.003388   4.668102            526.424171
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                       1229.730000                      462.420000
# 1                        387.760000                      254.610000
# 2                       1597.060000                      510.800000
# 3                       1074.960000                      573.610000
# 4                       1412.610000                      507.950000
# ...                             ...                             ...
# 3267                    1001.183584                      215.047358
# 3268                    1001.183584                      207.321086
# 3269                    1001.183584                       94.812545
# 3270                    1001.183584                      186.659040
# 3271                    1001.183584                      193.681735
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0             0.380000       380.920000           0.560000     201.890000
# 1             0.130000        38.330000           0.180000     131.750000
# 2             0.220000       495.920000           0.370000     234.180000
# 3             0.280000       332.480000           0.310000     275.850000
# 4             0.390000       271.130000           0.410000     315.390000
# ...                ...              ...                ...            ...
# 3267          0.200808       249.491721           0.300165     200.793553
# 3268          0.200808       249.491721           0.300165     200.793553
# 3269          0.200808       249.491721           0.300165     200.793553
# 3270          0.200808       249.491721           0.300165     200.793553
# 3271          0.200808       249.491721           0.300165     200.793553
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0          664.210000     8.730000        162.130000      277.310000
# 1           18.480000     3.220000         29.310000       25.730000
# 2          495.760000     7.770000        120.500000      168.720000
# 3          506.470000     9.890000        126.690000      180.600000
# 4          578.700000     6.880000        128.150000      275.650000
# ...               ...          ...               ...             ...
# 3267       312.931022     5.004608        100.026299      149.944522
# 3268       304.510230     5.004608        100.026299      149.944522
# 3269       258.930600     5.004608        100.026299      149.944522
# 3270       345.700257     5.004608        100.026299      149.944522
# 3271       359.948574     5.004608        100.026299      149.944522
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)
# 0            95.190000       69.890000          4.040000
# 1            43.920000       22.550000          0.980000
# 2            87.900000       80.930000          3.170000
# 3            71.170000       71.390000          3.050000
# 4            58.250000       66.870000          2.480000
# ...                ...             ...               ...
# 3267         49.838229       45.162176          2.205561
# 3268         49.838229       45.162176          2.205561
# 3269         49.838229       45.162176          2.205561
# 3270         49.838229       45.162176          2.205561
# 3271         49.838229       45.162176          2.205561
#
# [12011 rows x 17 columns]

# %%
data['Potability'] = data_cat

# %%
data
# Out:
#       Colour (TCU)  Turbidity (NTU)         pH  Conductivity (uS/cm)  \
# 0        28.080000         6.750000  12.070000           1994.980000
# 1         4.330000         0.180000   7.750000            655.630000
# 2        21.180000         5.540000   0.160000           1689.110000
# 3        24.820000         6.930000   8.850000           2675.590000
# 4        17.290000         7.740000   4.810000           2580.210000
# ...            ...              ...        ...                   ...
# 3267     15.006526         5.003388   8.989900            390.410231
# 3268     15.006526         5.003388   6.702547            329.266002
# 3269     15.006526         5.003388  11.491011            439.893618
# 3270     15.006526         5.003388   6.069616            415.886955
# 3271     15.006526         5.003388   4.668102            526.424171
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                       1229.730000                      462.420000
# 1                        387.760000                      254.610000
# 2                       1597.060000                      510.800000
# 3                       1074.960000                      573.610000
# 4                       1412.610000                      507.950000
# ...                             ...                             ...
# 3267                    1001.183584                      215.047358
# 3268                    1001.183584                      207.321086
# 3269                    1001.183584                       94.812545
# 3270                    1001.183584                      186.659040
# 3271                    1001.183584                      193.681735
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0             0.380000       380.920000           0.560000     201.890000
# 1             0.130000        38.330000           0.180000     131.750000
# 2             0.220000       495.920000           0.370000     234.180000
# 3             0.280000       332.480000           0.310000     275.850000
# 4             0.390000       271.130000           0.410000     315.390000
# ...                ...              ...                ...            ...
# 3267          0.200808       249.491721           0.300165     200.793553
# 3268          0.200808       249.491721           0.300165     200.793553
# 3269          0.200808       249.491721           0.300165     200.793553
# 3270          0.200808       249.491721           0.300165     200.793553
# 3271          0.200808       249.491721           0.300165     200.793553
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0          664.210000     8.730000        162.130000      277.310000
# 1           18.480000     3.220000         29.310000       25.730000
# 2          495.760000     7.770000        120.500000      168.720000
# 3          506.470000     9.890000        126.690000      180.600000
# 4          578.700000     6.880000        128.150000      275.650000
# ...               ...          ...               ...             ...
# 3267       312.931022     5.004608        100.026299      149.944522
# 3268       304.510230     5.004608        100.026299      149.944522
# 3269       258.930600     5.004608        100.026299      149.944522
# 3270       345.700257     5.004608        100.026299      149.944522
# 3271       359.948574     5.004608        100.026299      149.944522
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)   Potability
# 0            95.190000       69.890000          4.040000  non-potable
# 1            43.920000       22.550000          0.980000      potable
# 2            87.900000       80.930000          3.170000  non-potable
# 3            71.170000       71.390000          3.050000  non-potable
# 4            58.250000       66.870000          2.480000  non-potable
# ...                ...             ...               ...          ...
# 3267         49.838229       45.162176          2.205561  non-potable
# 3268         49.838229       45.162176          2.205561  non-potable
# 3269         49.838229       45.162176          2.205561  non-potable
# 3270         49.838229       45.162176          2.205561  non-potable
# 3271         49.838229       45.162176          2.205561  non-potable
#
# [12011 rows x 18 columns]

# %%
data['Potability'].value_counts()
# Out:
# potable        6200
# non-potable    5811
# Name: Potability, dtype: int64

# %%
from sklearn.preprocessing import OneHotEncoder
enc=  OneHotEncoder(sparse=False)
data['Potability'] = enc.fit_transform(data[['Potability']])
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
data
# Out:
#       Colour (TCU)  Turbidity (NTU)         pH  Conductivity (uS/cm)  \
# 0        28.080000         6.750000  12.070000           1994.980000
# 1         4.330000         0.180000   7.750000            655.630000
# 2        21.180000         5.540000   0.160000           1689.110000
# 3        24.820000         6.930000   8.850000           2675.590000
# 4        17.290000         7.740000   4.810000           2580.210000
# ...            ...              ...        ...                   ...
# 3267     15.006526         5.003388   8.989900            390.410231
# 3268     15.006526         5.003388   6.702547            329.266002
# 3269     15.006526         5.003388  11.491011            439.893618
# 3270     15.006526         5.003388   6.069616            415.886955
# 3271     15.006526         5.003388   4.668102            526.424171
#
#       Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                       1229.730000                      462.420000
# 1                        387.760000                      254.610000
# 2                       1597.060000                      510.800000
# 3                       1074.960000                      573.610000
# 4                       1412.610000                      507.950000
# ...                             ...                             ...
# 3267                    1001.183584                      215.047358
# 3268                    1001.183584                      207.321086
# 3269                    1001.183584                       94.812545
# 3270                    1001.183584                      186.659040
# 3271                    1001.183584                      193.681735
#
#       Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0             0.380000       380.920000           0.560000     201.890000
# 1             0.130000        38.330000           0.180000     131.750000
# 2             0.220000       495.920000           0.370000     234.180000
# 3             0.280000       332.480000           0.310000     275.850000
# 4             0.390000       271.130000           0.410000     315.390000
# ...                ...              ...                ...            ...
# 3267          0.200808       249.491721           0.300165     200.793553
# 3268          0.200808       249.491721           0.300165     200.793553
# 3269          0.200808       249.491721           0.300165     200.793553
# 3270          0.200808       249.491721           0.300165     200.793553
# 3271          0.200808       249.491721           0.300165     200.793553
#
#       Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0          664.210000     8.730000        162.130000      277.310000
# 1           18.480000     3.220000         29.310000       25.730000
# 2          495.760000     7.770000        120.500000      168.720000
# 3          506.470000     9.890000        126.690000      180.600000
# 4          578.700000     6.880000        128.150000      275.650000
# ...               ...          ...               ...             ...
# 3267       312.931022     5.004608        100.026299      149.944522
# 3268       304.510230     5.004608        100.026299      149.944522
# 3269       258.930600     5.004608        100.026299      149.944522
# 3270       345.700257     5.004608        100.026299      149.944522
# 3271       359.948574     5.004608        100.026299      149.944522
#
#       Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)  Potability
# 0            95.190000       69.890000          4.040000         1.0
# 1            43.920000       22.550000          0.980000         0.0
# 2            87.900000       80.930000          3.170000         1.0
# 3            71.170000       71.390000          3.050000         1.0
# 4            58.250000       66.870000          2.480000         1.0
# ...                ...             ...               ...         ...
# 3267         49.838229       45.162176          2.205561         1.0
# 3268         49.838229       45.162176          2.205561         1.0
# 3269         49.838229       45.162176          2.205561         1.0
# 3270         49.838229       45.162176          2.205561         1.0
# 3271         49.838229       45.162176          2.205561         1.0
#
# [12011 rows x 18 columns]

# %%
data = data.sample(frac=1)
data = data.reset_index()

data = data.drop(columns=['index'])
data
# Out:
#        Colour (TCU)  Turbidity (NTU)         pH  Conductivity (uS/cm)  \
# 0         15.800000         5.850000   1.250000           2130.140000
# 1         15.006526         5.003388   8.458797            328.579429
# 2         22.860000         5.480000   0.430000           2457.570000
# 3         24.480000         5.290000  11.700000           1703.950000
# 4          4.840000         0.650000   7.400000           1341.050000
# ...             ...              ...        ...                   ...
# 12006     24.880000         8.460000   6.360000           1558.290000
# 12007     27.900000         9.100000   4.710000           2639.350000
# 12008     12.510000         3.290000   7.110000            416.910000
# 12009      8.160000         1.860000   6.700000           1440.090000
# 12010     13.550000         2.110000   7.260000            699.660000
#
#        Total Dissolved Solids (mg/l)  Total Hardness (mg/l as CaCO3)  \
# 0                        1661.110000                       563.59000
# 1                        1001.183584                       241.76834
# 2                        1066.360000                       386.71000
# 3                        1190.930000                       316.55000
# 4                         120.150000                       231.77000
# ...                              ...                             ...
# 12006                    1019.810000                       352.41000
# 12007                    1479.000000                       452.68000
# 12008                     131.010000                        29.22000
# 12009                     708.320000                       219.69000
# 12010                     178.600000                       119.70000
#
#        Aluminium (mg/l)  Chloride (mg/l)  Total Iron (mg/l)  Sodium (mg/l)  \
# 0              0.360000       304.910000           0.430000     231.340000
# 1              0.200808       249.491721           0.300165     200.793553
# 2              0.350000       467.310000           0.370000     218.880000
# 3              0.300000       463.610000           0.380000     285.190000
# 4              0.190000       151.680000           0.190000      96.700000
# ...                 ...              ...                ...            ...
# 12006          0.220000       259.020000           0.400000     397.160000
# 12007          0.330000       284.480000           0.430000     295.450000
# 12008          0.010000        80.150000           0.280000      21.880000
# 12009          0.150000        13.070000           0.130000      92.030000
# 12010          0.180000         0.000000           0.070000       4.240000
#
#        Sulphate (mg/l)  Zinc (mg/l)  Magnesium (mg/l)  Calcium (mg/l)  \
# 0           520.410000     6.110000        177.240000      273.730000
# 1           313.885548     5.004608        100.026299      149.944522
# 2           761.960000     7.460000        171.570000      178.020000
# 3           668.280000     5.830000        133.660000      268.850000
# 4           195.960000     2.690000          1.480000       52.490000
# ...                ...          ...               ...             ...
# 12006       418.720000     8.390000        158.820000      286.010000
# 12007       713.050000     7.200000        107.040000      181.860000
# 12008       207.640000     4.110000         52.920000       43.230000
# 12009       259.300000     3.390000         78.770000       34.870000
# 12010         3.010000     2.950000         96.360000       61.740000
#
#        Potassium (mg/l)  Nitrate (mg/l)  Phosphate (mg/l)  Potability
# 0             69.930000       53.470000          2.520000         1.0
# 1             49.838229       45.162176          2.205561         1.0
# 2             88.120000       75.410000          4.250000         1.0
# 3             71.330000       73.800000          3.650000         1.0
# 4             22.930000        3.490000          0.190000         0.0
# ...                 ...             ...               ...         ...
# 12006         58.230000       77.330000          3.190000         1.0
# 12007         86.960000       83.650000          2.700000         1.0
# 12008          7.190000       40.750000          1.820000         0.0
# 12009         38.690000        7.400000          0.510000         0.0
# 12010         14.330000       28.820000          0.790000         0.0
#
# [12011 rows x 18 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x = data.iloc[:,:-1]
y = data.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=42,test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression

# %%
reg = LogisticRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = reg.predict(x_test)
y_pred
# Out:
# array([0., 0., 1., ..., 0., 1., 1.])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.8795782463928968

# %%
from sklearn.metrics import precision_score
precision_score(y_pred,y_test)
# Out:
# 0.8818129661503156

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1633,  228],
#        [ 206, 1537]], dtype=int64)

# %%
from sklearn.model_selection import learning_curve
import warnings
warnings.filterwarnings("ignore")

# %%
train_sizes, train_scores, valid_scores = learning_curve(
reg, x, y, train_sizes=np.linspace(0.05, 1.0, 30), cv=5,
)
train_mean = np.mean(train_scores,axis=1)
test_mean = np.mean(valid_scores,axis=1)
plt.subplots(1,figsize=(10,10))
plt.plot(train_sizes, train_mean, "r-+", linewidth=2, label="train")
plt.plot(train_sizes, test_mean, "b-", linewidth=3, label="valid")
plt.legend()

plt.show()
